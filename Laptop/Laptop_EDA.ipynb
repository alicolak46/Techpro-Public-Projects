# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("laptop.csv")
df
# Out:
#       Unnamed: 0 productType  \
# 0              0          HP
# 1              1      Casper
# 2              2        Dell
# 3              3      Casper
# 4              4      Casper
# ...          ...         ...
# 4936       30435      Casper
# 4937       30447      Casper
# 4938       31059      Casper
# 4939       31071      Casper
# 4940       31815      Casper
#
#                                             productLink productPrice  \
# 0     https://www.trendyol.com//hp/250-g8-core-i5-11...    10.999 TL
# 1     https://www.trendyol.com//casper/nirvana-x600-...    12.599 TL
# 2     https://www.trendyol.com//dell/vostro-3520-i5-...    33.999 TL
# 3     https://www.trendyol.com//casper/excalibur-g87...    16.299 TL
# 4     https://www.trendyol.com//casper/nirvana-c370-...     6.999 TL
# ...                                                 ...          ...
# 4936  https://www.trendyol.com//casper/excalibur-g87...    16.299 TL
# 4937  https://www.trendyol.com//gigabyte/g5-mf-i5-12...    17.275 TL
# 4938  https://www.trendyol.com//casper/excalibur-g87...    16.299 TL
# 4939  https://www.trendyol.com//gigabyte/g5-mf-i5-12...    17.275 TL
# 4940  https://www.trendyol.com//gigabyte/g5-mf-i5-12...    17.275 TL
#
#                                             productInfo productName
# 0     250 G8/Core I5-1135G7 İşlemci/ 8GB Ram/ 256GB ...      Laptop
# 1      Nirvana X600.139H-DF00X-G-F Intel Core i7-113...      Laptop
# 2     Vostro 3520 I5-1135G7 8 GB 256 GB SSD 15.6" Fh...      Laptop
# 3     Excalibur G870.1265-DFA0X-B Intel Core i7-1265...      Laptop
# 4     Nirvana C370.4020-4C00B Intel Celeron N4020 4G...      Laptop
# ...                                                 ...         ...
# 4936   Nirvana X600.139H-DF00X-G-F Intel Core i7-113...      Laptop
# 4937  IdeaPad 1 15ALC7 82R400F1TR R7-5700U 8GB 256GB...      Laptop
# 4938   Nirvana X600.139H-DF00X-G-F Intel Core i7-113...      Laptop
# 4939  IdeaPad 1 15ALC7 82R400F1TR R7-5700U 8GB 256GB...      Laptop
# 4940  IdeaPad 1 15ALC7 82R400F1TR R7-5700U 8GB 256GB...      Laptop
#
# [4941 rows x 6 columns]

# %%
#index zaten var ve doğru olduğu için Unnamed: 0 sütununu drop ettik
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#      productType                                        productLink  \
# 0             HP  https://www.trendyol.com//hp/250-g8-core-i5-11...
# 1         Casper  https://www.trendyol.com//casper/nirvana-x600-...
# 2           Dell  https://www.trendyol.com//dell/vostro-3520-i5-...
# 3         Casper  https://www.trendyol.com//casper/excalibur-g87...
# 4         Casper  https://www.trendyol.com//casper/nirvana-c370-...
# ...          ...                                                ...
# 4936      Casper  https://www.trendyol.com//casper/excalibur-g87...
# 4937      Casper  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
# 4938      Casper  https://www.trendyol.com//casper/excalibur-g87...
# 4939      Casper  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
# 4940      Casper  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
#
#      productPrice                                        productInfo  \
# 0       10.999 TL  250 G8/Core I5-1135G7 İşlemci/ 8GB Ram/ 256GB ...
# 1       12.599 TL   Nirvana X600.139H-DF00X-G-F Intel Core i7-113...
# 2       33.999 TL  Vostro 3520 I5-1135G7 8 GB 256 GB SSD 15.6" Fh...
# 3       16.299 TL  Excalibur G870.1265-DFA0X-B Intel Core i7-1265...
# 4        6.999 TL  Nirvana C370.4020-4C00B Intel Celeron N4020 4G...
# ...           ...                                                ...
# 4936    16.299 TL   Nirvana X600.139H-DF00X-G-F Intel Core i7-113...
# 4937    17.275 TL  IdeaPad 1 15ALC7 82R400F1TR R7-5700U 8GB 256GB...
# 4938    16.299 TL   Nirvana X600.139H-DF00X-G-F Intel Core i7-113...
# 4939    17.275 TL  IdeaPad 1 15ALC7 82R400F1TR R7-5700U 8GB 256GB...
# 4940    17.275 TL  IdeaPad 1 15ALC7 82R400F1TR R7-5700U 8GB 256GB...
#
#      productName
# 0         Laptop
# 1         Laptop
# 2         Laptop
# 3         Laptop
# 4         Laptop
# ...          ...
# 4936      Laptop
# 4937      Laptop
# 4938      Laptop
# 4939      Laptop
# 4940      Laptop
#
# [4941 rows x 5 columns]

# %%
df = df.rename(columns={'productType': 'product_type', 'productLink': 'product_link','productPrice': 'product_price','productInfo': 'product_info','productName': 'product_name' })
df
# Out:
#      product_type                                       product_link  \
# 0              HP  https://www.trendyol.com//hp/250-g8-core-i5-11...
# 1          Casper  https://www.trendyol.com//casper/nirvana-x600-...
# 2            Dell  https://www.trendyol.com//dell/vostro-3520-i5-...
# 3          Casper  https://www.trendyol.com//casper/excalibur-g87...
# 4          Casper  https://www.trendyol.com//casper/nirvana-c370-...
# ...           ...                                                ...
# 4936       Casper  https://www.trendyol.com//casper/excalibur-g87...
# 4937       Casper  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
# 4938       Casper  https://www.trendyol.com//casper/excalibur-g87...
# 4939       Casper  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
# 4940       Casper  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
#
#      product_price                                       product_info  \
# 0        10.999 TL  250 G8/Core I5-1135G7 İşlemci/ 8GB Ram/ 256GB ...
# 1        12.599 TL   Nirvana X600.139H-DF00X-G-F Intel Core i7-113...
# 2        33.999 TL  Vostro 3520 I5-1135G7 8 GB 256 GB SSD 15.6" Fh...
# 3        16.299 TL  Excalibur G870.1265-DFA0X-B Intel Core i7-1265...
# 4         6.999 TL  Nirvana C370.4020-4C00B Intel Celeron N4020 4G...
# ...            ...                                                ...
# 4936     16.299 TL   Nirvana X600.139H-DF00X-G-F Intel Core i7-113...
# 4937     17.275 TL  IdeaPad 1 15ALC7 82R400F1TR R7-5700U 8GB 256GB...
# 4938     16.299 TL   Nirvana X600.139H-DF00X-G-F Intel Core i7-113...
# 4939     17.275 TL  IdeaPad 1 15ALC7 82R400F1TR R7-5700U 8GB 256GB...
# 4940     17.275 TL  IdeaPad 1 15ALC7 82R400F1TR R7-5700U 8GB 256GB...
#
#      product_name
# 0          Laptop
# 1          Laptop
# 2          Laptop
# 3          Laptop
# 4          Laptop
# ...           ...
# 4936       Laptop
# 4937       Laptop
# 4938       Laptop
# 4939       Laptop
# 4940       Laptop
#
# [4941 rows x 5 columns]

# %%
#product_name Column 
df.product_name.value_counts()
# Out:
# Laptop    4941
# Name: product_name, dtype: int64

# %%
#data setinin "laptop" olduğu bilindiği için, sütunu drop ettik.

df.drop(columns=["product_name"], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4941 entries, 0 to 4940
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_type   4941 non-null   object
#  1   product_link   4941 non-null   object
#  2   product_price  4941 non-null   object
#  3   product_info   4941 non-null   object
# dtypes: object(4)
# memory usage: 154.5+ KB

# %%
#product_type Column

df.product_type.value_counts()
# Out:
# HP                1178
# Casper             931
# LENOVO             867
# ASUS               750
# Dell               288
# Gigabyte           283
# ACER               201
# Monster            196
# MSI                 98
# Apple               72
# Huawei              19
# GPTURKGRUP          12
# Toshiba              9
# Microsoft            5
# Technopc             5
# Game Garaj           4
# DTS Teknoloji        4
# EXA                  3
# HPE                  2
# Honor                2
# Alienware            2
# I-LIFE DIGITAL       2
# Dynabook             1
# ILIFE                1
# Everest              1
# Xiaomi               1
# Hometech             1
# Samsung              1
# FOSILTECH            1
# I-Life               1
# Name: product_type, dtype: int64

# %%
# product_type de hata var. yanlış veri çekilmiş baştan yapılmalı
df[df['product_type'].str.contains('HP')].sample(5)
# Out:
#      product_type                                       product_link  \
# 1001           HP  https://www.trendyol.com//asus/vivobook-x1502z...
# 3832           HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 3643           HP  https://www.trendyol.com//hp/victus-15-fa1028n...
# 3847           HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 3708           HP  https://www.trendyol.com//hp/victus-16-ryzen-7...
#
#      product_price                                       product_info
# 1001     25.440 TL  Vivobook X1502ZA-EJ10667 CI5-1235U 8GB 512GB F...
# 3832     51.633 TL  Victus 16 i7-13700H 24GB 256GB SSD RTX4070/8GB...
# 3643  42.093,10 TL  Victus 15-FA1028NTA33 İntel i7 13700H 32GB 512...
# 3847     53.831 TL  Victus 16 i7 13700H 24GB 1TB SSD RTX4060/8GB 1...
# 3708     59.999 TL  Victus 16 Ryzen 7-6800H 8GB 2TB RTX3050Ti/4GB ...

# %%
df[df['product_type'].str.contains('HP')].sample(5)
# Out:
#      product_type                                       product_link  \
# 4316           HP  https://www.trendyol.com//hp/probook-455-g9-r5...
# 622            HP  https://www.trendyol.com//asus/rog-zephyrus-g1...
# 4248           HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 4128           HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 4155           HP  https://www.trendyol.com//hp/victus-16-i7-1370...
#
#      product_price                                       product_info
# 4316     20.246 TL  PROBOOK 455 G9 R5 5625U 32GB 1TB SSD 15.6" FHD...
# 622     144.999 TL  ROG Zephyrus G16 GU603ZU-N3015 Intel Core i7 1...
# 4248     70.436 TL  Victus 16 i7-13700H 40GB 2TB SSD RTX4050/6GB 1...
# 4128     54.954 TL  Victus 16 i7-13700H 8GB 256GB SSD RTX4050/6GB ...
# 4155     72.728 TL  Victus 16 i7-13700H 40GB 256GB SSD RTX4070/8GB...

# %%
df[df['product_info'].str.contains('İdeapad')]
# Out:
#      product_type                                       product_link  \
# 2496           HP  https://www.trendyol.com//lenovo/ideapad-gamin...
# 3188         ASUS  https://www.trendyol.com//lenovo/ideapad-gamin...
# 3513           HP  https://www.trendyol.com//lenovo/ideapad-gamin...
# 3515       LENOVO  https://www.trendyol.com//lenovo/ideapad-gamin...
# 3541           HP  https://www.trendyol.com//lenovo/ideapad-gamin...
#
#      product_price                                       product_info
# 2496     37.999 TL  İdeapad Gaming 3 15IAH7 64gb 2tb SSD 6GB RTX30...
# 3188     33.999 TL  İdeapad Gaming 3 15IAH7 32gb 1tb SSD 6GB RTX30...
# 3513     92.170 TL  İdeapad Gaming 3 15IAH7 32gb 2tb SSD 6GB RTX30...
# 3515     33.999 TL  İdeapad Gaming 3 15IAH7 64gb 1tb SSD 6GB RTX30...
# 3541     44.314 TL  İdeapad Gaming 3 15IAH7 64gb 2tb SSD 6GB RTX30...

# %%
r'https://www.trendyol.com//([^/]+)/'
# Out:
# 'https://www.trendyol.com//([^/]+)/'

# %%
#product_type yerine Brand sütunu oluşturalım.
df['Brand'] = df['product_link'].str.extract(r'https://www.trendyol.com//([^/]+)/')[0].str.upper()
df.sample(5)
# Out:
#      product_type                                       product_link  \
# 3645           HP  https://www.trendyol.com//hp/victus-15-fa1028n...
# 3371         ASUS  https://www.trendyol.com//asus/rog-strix-g17-g...
# 905        LENOVO  https://www.trendyol.com//acer/aspire-3-a315-5...
# 4443       LENOVO  https://www.trendyol.com//lenovo/v15-g3-i5-123...
# 1852       LENOVO  https://www.trendyol.com//hp/250-g10-intel-cor...
#
#      product_price                                       product_info   Brand
# 3645  38.338,32 TL  Victus 15-FA1028NTA5 İntel i7 13700H 16GB 512G...      HP
# 3371  69.170,10 TL  Rog Strıx G17 G713PVA50-LL091A50 Amd Ryzen 9 7...    ASUS
# 905      15.499 TL  Aspire 3 A315-56 Intel Core I3-1005g1 8 Gb 256...    ACER
# 4443  22.240,84 TL  V15 G3 i5-1235U 16GB 256GB SSD 15.6" FHD Windo...  LENOVO
# 1852     59.999 TL  250 G10 Intel Core I5 1335U 32gb 1TB SSD MX550...      HP

# %%
#Brand Column

df.Brand.value_counts().head(10)
# Out:
# HP          1183
# CASPER       908
# LENOVO       880
# ASUS         745
# GIGABYTE     296
# DELL         280
# MONSTER      203
# ACER         197
# MSI          103
# APPLE         66
# Name: Brand, dtype: int64

# %%
#index zaten var ve doğru olduğu için Unnamed: 0 sütununu drop ettik

df = df.drop('product_type', axis=1)
df.head()
# Out:
#                                         product_link product_price  \
# 0  https://www.trendyol.com//hp/250-g8-core-i5-11...     10.999 TL
# 1  https://www.trendyol.com//casper/nirvana-x600-...     12.599 TL
# 2  https://www.trendyol.com//dell/vostro-3520-i5-...     33.999 TL
# 3  https://www.trendyol.com//casper/excalibur-g87...     16.299 TL
# 4  https://www.trendyol.com//casper/nirvana-c370-...      6.999 TL
#
#                                         product_info   Brand
# 0  250 G8/Core I5-1135G7 İşlemci/ 8GB Ram/ 256GB ...      HP
# 1   Nirvana X600.139H-DF00X-G-F Intel Core i7-113...  CASPER
# 2  Vostro 3520 I5-1135G7 8 GB 256 GB SSD 15.6" Fh...    DELL
# 3  Excalibur G870.1265-DFA0X-B Intel Core i7-1265...  CASPER
# 4  Nirvana C370.4020-4C00B Intel Celeron N4020 4G...  CASPER

# %%
# Brand sütununu başa alalım.

df = df[['Brand', 'product_link', 'product_info', 'product_price']]
df.head()
# Out:
#     Brand                                       product_link  \
# 0      HP  https://www.trendyol.com//hp/250-g8-core-i5-11...
# 1  CASPER  https://www.trendyol.com//casper/nirvana-x600-...
# 2    DELL  https://www.trendyol.com//dell/vostro-3520-i5-...
# 3  CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 4  CASPER  https://www.trendyol.com//casper/nirvana-c370-...
#
#                                         product_info product_price
# 0  250 G8/Core I5-1135G7 İşlemci/ 8GB Ram/ 256GB ...     10.999 TL
# 1   Nirvana X600.139H-DF00X-G-F Intel Core i7-113...     12.599 TL
# 2  Vostro 3520 I5-1135G7 8 GB 256 GB SSD 15.6" Fh...     33.999 TL
# 3  Excalibur G870.1265-DFA0X-B Intel Core i7-1265...     16.299 TL
# 4  Nirvana C370.4020-4C00B Intel Celeron N4020 4G...      6.999 TL

# %%
#product_link Column

#Linklerin farklı internet sitelerinden alınma ihtimaline karşı, internet sitelerinin ismini check ettik.

# %%
# örn: https://www.trendyol.com//hp/250-g8-core-i5-1135g7-islemci-8gb-ram-256gb-ssd-15-6-fhd-freedos-laptop-komur-grisi-853u8es-p-773440890
df.product_link.str.split("//")
# Out:
# 0       [https:, www.trendyol.com, hp/250-g8-core-i5-1...
# 1       [https:, www.trendyol.com, casper/nirvana-x600...
# 2       [https:, www.trendyol.com, dell/vostro-3520-i5...
# 3       [https:, www.trendyol.com, casper/excalibur-g8...
# 4       [https:, www.trendyol.com, casper/nirvana-c370...
#                               ...
# 4936    [https:, www.trendyol.com, casper/excalibur-g8...
# 4937    [https:, www.trendyol.com, gigabyte/g5-mf-i5-1...
# 4938    [https:, www.trendyol.com, casper/excalibur-g8...
# 4939    [https:, www.trendyol.com, gigabyte/g5-mf-i5-1...
# 4940    [https:, www.trendyol.com, gigabyte/g5-mf-i5-1...
# Name: product_link, Length: 4941, dtype: object

# %%
df.product_link.str.split("/").str[2]
# Out:
# 0       www.trendyol.com
# 1       www.trendyol.com
# 2       www.trendyol.com
# 3       www.trendyol.com
# 4       www.trendyol.com
#               ...
# 4936    www.trendyol.com
# 4937    www.trendyol.com
# 4938    www.trendyol.com
# 4939    www.trendyol.com
# 4940    www.trendyol.com
# Name: product_link, Length: 4941, dtype: object

# %%
#tüm ürünler trendyol'dan temin edilmiş.
df.product_link.str.split("/").str[2].str.split(".").str[1].value_counts()
# Out:
# trendyol    4941
# Name: product_link, dtype: int64

# %%
#product_price Column

df.product_price
# Out:
# 0       10.999 TL
# 1       12.599 TL
# 2       33.999 TL
# 3       16.299 TL
# 4        6.999 TL
#           ...
# 4936    16.299 TL
# 4937    17.275 TL
# 4938    16.299 TL
# 4939    17.275 TL
# 4940    17.275 TL
# Name: product_price, Length: 4941, dtype: object

# %%
df.product_price = df.product_price.str.strip("TL")

# %%
df.product_price = df.product_price.astype("string").str.extract(r"(\d*\.\d{3})")

# %%
df.product_price = df.product_price.str.replace(".","").astype(int)

df.product_price
# Out:
# 0       10999
# 1       12599
# 2       33999
# 3       16299
# 4        6999
#         ...
# 4936    16299
# 4937    17275
# 4938    16299
# 4939    17275
# 4940    17275
# Name: product_price, Length: 4941, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4941 entries, 0 to 4940
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Brand          4941 non-null   object
#  1   product_link   4941 non-null   object
#  2   product_info   4941 non-null   object
#  3   product_price  4941 non-null   int32
# dtypes: int32(1), object(3)
# memory usage: 135.2+ KB

# %%
#Product_info Column

print(df.product_link[1])
print(df.product_info[1])

print()

print(df.product_link[33])
print(df.product_info[33])

print()

print(df.product_link[155])
print(df.product_info[155])


print()

print(df.product_link[1071])
print(df.product_info[1071])
# Out:
# https://www.trendyol.com//casper/nirvana-x600-139h-df00x-g-f-intel-core-i7-11390h-32-gb-ram-1tb-nvme-ssd-gen4-freedos-p-773800427
#  Nirvana X600.139H-DF00X-G-F Intel Core i7-11390H 32 GB RAM 1TB NVME SSD GEN4 Freedos
#
# https://www.trendyol.com//lenovo/nb-v15-ryzen-5-7520u-16gb-512ssd-freedos-15-6-fhd-tasinabilir-bilgisayar-82yu00qytx-p-742133243
# 15-FC0060NT AMD Ryzen 5-7520U 16GB 512GB DOS 15.6" FHD Siyah Laptop (HP Türkiye Garantili) 8M1T2EA
#
# https://www.trendyol.com//lenovo/ideapad-3-15itl6-i5-1155g7-8gb-256gb-ssd-15-6-fhd-freedos-82h803frtx-p-738590755
# IdeaPad 3 15ITL6 i5-1155G7 8GB 256GB SSD 15.6" FHD Freedos 82H803FRTX
#
# https://www.trendyol.com//dell/vostro-3400-intel-core-i3-1115g4-4gb-1tb-hdd-1tb-ssd-freedos-14-hd-bilgisayar-c-h-snertech-p-786590381
# Vostro 3400 Intel Core i3 1115G4 4GB 1TB HDD 1TB SSD Freedos 14" HD Bilgisayar Ç.H-SnerTech

# %%
# Processor sütunu oluşturalım.
# Extract işlemlerini ayrı ayrı yap ve sadece ilk sütunu al

df['Processor'] = df['product_info'].str.extract(r'\b((([İiIı][3579]|Celeron|Cel|R[3579]|Ryzen\s?[3579]|RYZEN\s?[3579])\s?[^\s]+|Mac[bB]ook\sAir|Mac[bB]ook\sPro)\b|\b\w*(i7)\b)')[0]
df.sample(5)
# Out:
#        Brand                                       product_link  \
# 1568    ASUS  https://www.trendyol.com//asus/x515ea-bq3228-i...
# 1449  CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 1773      HP  https://www.trendyol.com//hp/core-i7-1255u-8gb...
# 3341  CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 1301   APPLE  https://www.trendyol.com//apple/macbook-air-13...
#
#                                            product_info  product_price  \
# 1568  X515EA-BQ3228 i5-1135G7 16GB 512GB SSD+32GB Op...          27999
# 1449  Excalibur G870.1265-DFA0X-B Intel Core i7-1265...          14099
# 1773  Core I7-1255u 8gb Ram 512gb Ssd Freedos 6g0b7e...          35499
# 3341  Excalibur G870.1265-DFA0X-B Intel Core i7-1265...          65043
# 1301  Macbook Air 13.6" M2 8c Cpu 10c Gpu 8 Gb 512 G...          37999
#
#         Processor
# 1568    i5-1135G7
# 1449    i7-12650H
# 1773     I7-1255u
# 3341    i7-12650H
# 1301  Macbook Air

# %%
df.Processor.isnull().sum()
# Out:
# 103

# %%
df[df.Processor.isnull()]
# Out:
#         Brand                                       product_link  \
# 35     LENOVO  https://www.trendyol.com//lenovo/v15-82yu00met...
# 63    SAMSUNG  https://www.trendyol.com//samsung/galaxy-book-...
# 79       ASUS  https://www.trendyol.com//asus/x515ma-ej680w0w...
# 84         HP  https://www.trendyol.com//hp/250-g8-853u7es-ci...
# 139      ASUS  https://www.trendyol.com//asus/vivobook-x1502z...
# ...       ...                                                ...
# 3340     ASUS  https://www.trendyol.com//asus/rog-strix-g16-g...
# 3513   LENOVO  https://www.trendyol.com//lenovo/ideapad-gamin...
# 3515   LENOVO  https://www.trendyol.com//lenovo/ideapad-gamin...
# 3541   LENOVO  https://www.trendyol.com//lenovo/ideapad-gamin...
# 4925   LENOVO  https://www.trendyol.com//lenovo/ideapad-3-int...
#
#                                            product_info  product_price  \
# 35    V15 82YU00METX 7120U 8GB 256SSD 15.6" FullHD F...          39499
# 63                   Galaxy Book S Snapdragon Işlemcili          20950
# 79    X515MA-EJ680W0W N4020 12GB 128GB eMMC Windows ...          37999
# 84    250 G8 853U7ES Cİ5-1135G7 8GB 256 SSD 15.6" FD...          29999
# 139   Vivobook X1502ZA-EJ1066AS CI5-1235U 16GB 512GB...          20999
# ...                                                 ...            ...
# 3340  Rog Strix G16 G614JZ-N3038-WI7 13650HX 32GB 1T...          33999
# 3513  İdeapad Gaming 3 15IAH7 32gb 2tb SSD 6GB RTX30...          92170
# 3515  İdeapad Gaming 3 15IAH7 64gb 1tb SSD 6GB RTX30...          33999
# 3541  İdeapad Gaming 3 15IAH7 64gb 2tb SSD 6GB RTX30...          44314
# 4925  Extensa Ex215-54 Corei5 1135g7 8 gb 512 gb Ssd...          11740
#
#      Processor
# 35         NaN
# 63         NaN
# 79         NaN
# 84         NaN
# 139        NaN
# ...        ...
# 3340       NaN
# 3513       NaN
# 3515       NaN
# 3541       NaN
# 4925       NaN
#
# [103 rows x 5 columns]

# %%
df.dropna(subset=['Processor'],inplace=True)

# %%
df.Processor.isnull().sum()
# Out:
# 0

# %%
#RAM sütunu ekleyelim.

df['RAM'] = df['product_info'].str.extract(r'\b(\d\d*)\s?(G|g|GB|GBB|[Gg]b)\b')[0]

# %%
df.RAM.isnull().sum()
# Out:
# 10

# %%
df[df.RAM.isnull()]
# Out:
#        Brand                                       product_link  \
# 220   HUAWEI  https://www.trendyol.com//huawei/matebook-14s-...
# 270   HUAWEI  https://www.trendyol.com//huawei/matebook-x-pr...
# 351      MSI  https://www.trendyol.com//msi/modern-15-b12mo-...
# 558     ACER  https://www.trendyol.com//acer/predator-core-i...
# 775   HUAWEI  https://www.trendyol.com//huawei/matebook-16s-...
# 1023  LENOVO  https://www.trendyol.com//lenovo/82jd002atx-i7...
# 1031  YASOMI  https://www.trendyol.com//yasomi/twin-up-2tb-s...
# 1193    ASUS  https://www.trendyol.com//asus/rog-strix-scar-...
# 1701      HP  https://www.trendyol.com//hp/250-g8-i5-1135g7-...
# 3310  LENOVO  https://www.trendyol.com//lenovo/ideapad-slim-...
#
#                                            product_info  product_price  \
# 220             Matebook 14s Windows 11 Home i7 - Yeşil          27999
# 270   MateBook X Pro 2023 Windows 11 Pro i7 Yeni - K...          30499
# 351   Modern 15 B12mo I5 1235u 8 Ram 512 Ssd Win 11 ...          13699
# 558   Predator Core I9 13900hx 24 B 1tb Ssd Rtx 4070...          15799
# 775   MateBook 16s Windows 11 Home i9 Yeni - Uzay Gr...          38999
# 1023        82jd002atx I7/16/512/6gvga/16/w10h Notebook          24264
# 1031  Twin-up 2tb Ssd 16" Core I7 Ddr4 10870h Işlemc...          10599
# 1193  Rog Strix Scar 16 G634JZ-NM044 GAMİNG i9 13980...          15399
# 1701  250 G8 I5-1135g7 16gb256gb Ssd 853u8es081 W11p...          59999
# 3310        IdeaPad Slim 3 15.6" FHD, AMD Ryzen 3 7320U          27999
#
#                     Processor  RAM
# 220                        i7  NaN
# 270                   i7 Yeni  NaN
# 351                  I5 1235u  NaN
# 558                I9 13900hx  NaN
# 775                   i9 Yeni  NaN
# 1023  I7/16/512/6gvga/16/w10h  NaN
# 1031                  I7 Ddr4  NaN
# 1193               i9 13980HX  NaN
# 1701                I5-1135g7  NaN
# 3310            Ryzen 3 7320U  NaN

# %%
df.dropna(subset=['RAM'],inplace=True)

# %%
df.RAM.isnull().sum()
# Out:
# 0

# %%
df.RAM =df.RAM.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4828 entries, 0 to 4940
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Brand          4828 non-null   object
#  1   product_link   4828 non-null   object
#  2   product_info   4828 non-null   object
#  3   product_price  4828 non-null   int32
#  4   Processor      4828 non-null   object
#  5   RAM            4828 non-null   int32
# dtypes: int32(2), object(4)
# memory usage: 226.3+ KB

# %%
#Storage sütunu oluşturalım.

df['Storage'] = df['product_info'].str.extract(r'\b(120|128|240|250|256|512|500|1|2|4)\s?([GgTt][Bb])?\s*(SSD|ssd|Ssd|SD)?\b')[0]
df.sample(5)
# Out:
#          Brand                                       product_link  \
# 2279    LENOVO  https://www.trendyol.com//lenovo/ideapad-3-int...
# 3907        HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 2112        HP  https://www.trendyol.com//hp/250-g8-intel-core...
# 3160  GIGABYTE  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
# 1098      ASUS  https://www.trendyol.com//asus/zenbook-14-oled...
#
#                                            product_info  product_price  \
# 2279  IdeaPad 3 Intel Core i5-1155G7 8GB Ram 256Gb R...          24737
# 3907  Victus 16 i7-13700H 16GB 256GB SSD RTX4050/6GB...          68284
# 2112  250 G8 Intel Core i5 1135G7 16GB 256GB SSD Win...          27999
# 3160  Abra A5 V20.4.4 Intel Core i5 12450H 16 GB RAM...          30356
# 1098  Zenbook 14 Oled Ux3402za-km501w Intel Core I5 ...           8499
#
#       Processor  RAM Storage
# 2279  i5-1155G7    8     256
# 3907  i7-13700H   16     256
# 2112  i5 1135G7   16     250
# 3160  i5 12450H   16       4
# 1098   I5 1240p   16     512

# %%
df.product_link[880]
# Out:
# 'https://www.trendyol.com//msi/modern-15-a5m-091xtr-r5-5500u-8gb-ddr4-uma-256gb-ssd-15-6-fhd-dos-koyu-gri-p-191051743'

# %%
df.Storage.isnull().sum()
# Out:
# 6

# %%
df[df.Storage.isnull()]
# Out:
#        Brand                                       product_link  \
# 151   LENOVO  https://www.trendyol.com//lenovo/v15-g3-82tt00...
# 818     ASUS  https://www.trendyol.com//asus/notebook-laptop...
# 848   CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 861      MSI  https://www.trendyol.com//msi/katana-17-b12vfk...
# 1118  LENOVO  https://www.trendyol.com//lenovo/legion-5-pro-...
# 1508    DELL  https://www.trendyol.com//dell/g16-7630-8gb-rt...
#
#                                            product_info  product_price  \
# 151   V15 G3 82TT00C6TX i7-1255U 8G 512G SSD 15.6 FH...          29999
# 818   Notebook Laptop F515ea-ej3281,fhd Ekran, Intel...          30399
# 848   Excalibur G870.1265-BQA0X-B Intel Core i7-1265...           9999
# 861   Katana 17 B12vfk-403tr Dizüstü Bilgisayar, Cor...          29064
# 1118  Legion 5 Pro Intel Core I7-12700h 82rf00sutx 3...          76160
# 1508  G16 7630 8GB RTX4070 i9-13900HX 16GB1TB SSD 16...          18889
#
#        Processor  RAM Storage
# 151     i7-1255U    8     NaN
# 818    I5-1135g7    8     NaN
# 848    i7-12650H   16     NaN
# 861    I7-12650h   16     NaN
# 1118   I7-12700h   32     NaN
# 1508  i9-13900HX    8     NaN

# %%
df.dropna(subset=['Storage'],inplace=True)

# %%
df.Storage.isnull().sum()
# Out:
# 0

# %%
df.Storage =df.Storage.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4822 entries, 0 to 4940
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Brand          4822 non-null   object
#  1   product_link   4822 non-null   object
#  2   product_info   4822 non-null   object
#  3   product_price  4822 non-null   int32
#  4   Processor      4822 non-null   object
#  5   RAM            4822 non-null   int32
#  6   Storage        4822 non-null   int32
# dtypes: int32(3), object(4)
# memory usage: 244.9+ KB

# %%
# Screen_Size sütunu oluşturalım

df['Screen_Size'] = df['product_info'].str.extract(r'((\d{2}[.,]\d)\s?|\d+")|(\d+\s?in[cç])|(\d{2}[.,]\d)\s?in[cç]')[0]
df.sample(5)
# Out:
#          Brand                                       product_link  \
# 3985        HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 2122      ACER  https://www.trendyol.com//acer/extensa-ex215-5...
# 3927  GIGABYTE  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
# 199        MSI  https://www.trendyol.com//msi/17-b12vfk-1031xt...
# 4090        HP  https://www.trendyol.com//hp/victus-16-i7-1370...
#
#                                            product_info  product_price  \
# 3985  Victus 16 i7-13700H 48GB 512GB SSD RTX4050/6GB...          64262
# 2122  Extensa Ex215-54 Intel Core I5 1135g7 8 Gb 512...          27900
# 3927  Abra A5 V20.4.4 Intel Core i5 12450H 16 GB RAM...          64823
# 199   17 B12VFK-1031XTR i5 12450H 16GB 512GB RTX4060...          43499
# 4090  Victus 16 i7-13700H 32GB 256GB SSD RTX4050/6GB...          67770
#
#       Processor  RAM  Storage Screen_Size
# 3985  i7-13700H   48      512        16.1
# 2122  I5 1135g7    8      512        15.6
# 3927  i5 12450H   16        4        20.4
# 199   i5 12450H   16      512        17.3
# 4090  i7-13700H   32      256        16.1

# %%
df.Screen_Size.isnull().sum()
# Out:
# 193

# %%
df.Screen_Size.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       15.6
# 1       00.1
# 2       15.6
# 3       70.1
# 4       70.4
#         ...
# 4936    00.1
# 4937    15.6
# 4938    00.1
# 4939    15.6
# 4940    15.6
# Name: Screen_Size, Length: 4822, dtype: object>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4822 entries, 0 to 4940
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Brand          4822 non-null   object
#  1   product_link   4822 non-null   object
#  2   product_info   4822 non-null   object
#  3   product_price  4822 non-null   int32
#  4   Processor      4822 non-null   object
#  5   RAM            4822 non-null   int32
#  6   Storage        4822 non-null   int32
#  7   Screen_Size    4629 non-null   object
# dtypes: int32(3), object(5)
# memory usage: 282.5+ KB

# %%
df[df.Screen_Size.isnull()]
# Out:
#        Brand                                       product_link  \
# 37    LENOVO  https://www.trendyol.com//lenovo/ideapad-3-int...
# 44    HUAWEI  https://www.trendyol.com//huawei/matebook-d16-...
# 48    LENOVO  https://www.trendyol.com//lenovo/ideapad-3-sli...
# 52     APPLE  https://www.trendyol.com//apple/macbook-air-13...
# 97      ASUS  https://www.trendyol.com//asus/tuf-gaming-f15-...
# ...      ...                                                ...
# 4503  LENOVO  https://www.trendyol.com//lenovo/nb-e14-thinkp...
# 4520    ACER  https://www.trendyol.com//acer/predator-intel-...
# 4521    ACER  https://www.trendyol.com//acer/predator-intel-...
# 4527    ACER  https://www.trendyol.com//acer/predator-intel-...
# 4529    ACER  https://www.trendyol.com//acer/predator-intel-...
#
#                                            product_info  product_price  \
# 37    Ideapad 3 Intel Core İ3-1215U 8gb 512gb Ssd Fr...          29999
# 44    Matebook D16 Intel Core i5-12450H 16GB 512GB S...          12999
# 48    Ideapad 3 Slim Case Intel Core I5-12450h 8gb 5...          28499
# 52              Macbook Air 13'' M1 8gb 256gb Ssd Gümüş          28986
# 97    Tuf Gaming F15 Fx506hf-hn030w Intel Core I5-11...          12199
# ...                                                 ...            ...
# 4503  Nb E14 Thınkpad 21e30087tx I7-1255u 16gb 512ss...          22499
# 4520  Predator Intel I7 12700h 64gb 512gb Ssd 8gb Rt...          18499
# 4521  Predator Intel I7 12700h 32gb 1tb Ssd 8gb Rtx3...          35499
# 4527  Predator Intel I7 12700h 32gb 1tb Ssd 8gb Rtx3...          61599
# 4529  Predator Intel I7 12700h 32gb 512gb Ssd 8gb Rt...          29999
#
#         Processor  RAM  Storage Screen_Size
# 37       İ3-1215U    8      512         NaN
# 44      i5-12450H   16      512         NaN
# 48      I5-12450h    8      512         NaN
# 52    Macbook Air    8      256         NaN
# 97      I5-11400h    8      512         NaN
# ...           ...  ...      ...         ...
# 4503     I7-1255u   16      512         NaN
# 4520    I7 12700h   64      512         NaN
# 4521    I7 12700h   32        1         NaN
# 4527    I7 12700h   32        1         NaN
# 4529    I7 12700h   32      512         NaN
#
# [193 rows x 8 columns]

# %%
df['Screen_Size'] = df['Screen_Size'].str.strip('"').str.strip(" ").str.replace(",",".").astype(float)

# %%
df['Screen_Size'].median()
# Out:
# 15.6

# %%
df['Screen_Size'].unique()
# Out:
# array([15.6,  0.1, 70.1, 70.4, 20.4, 13. , 20.3,  0.5, 17.3, 20.7, 16. ,
#        13.3,  nan, 13.6, 14. , 23.3, 20.1, 17. , 14.1, 50.1, 16.1, 20.6,
#        21.1, 14.4, 11.1, 16.8, 23.2, 17.4, 18. , 14.6, 11.6, 13.4, 14.5,
#        21.2, 20.2, 13.5, 12.4])

# %%
df['Screen_Size'].fillna(15.6, inplace= True)

# %%
df.Screen_Size.isnull().sum()
# Out:
# 0

# %%
df['Screen_Size'].value_counts().head(10)
# Out:
# 15.6    2512
# 16.1     685
# 70.1     295
# 20.4     278
# 20.3     223
# 14.0     220
# 16.0     198
# 17.3     135
# 0.1       59
# 13.0      33
# Name: Screen_Size, dtype: int64

# %%
valid_sizes = [17.3, 17.0, 16.1, 16, 15.6, 14.0, 13.0]

# Eğer Screen_Size 11.1 ise yeni değerini 16.0 yap
df.loc[df['Screen_Size'] == 11.1, 'Screen_Size'] = 16.0

# Eğer Screen_Size 14.1 ise yeni değerini 14.0 yap
df.loc[df['Screen_Size'] == 14.1, 'Screen_Size'] = 14.0

# Eğer Screen_Size valid_sizes listesinde değilse, o zaman 15.6 yap
df.loc[~df['Screen_Size'].isin(valid_sizes), 'Screen_Size'] = 15.6

# %%
df['Screen_Size'].value_counts()
# Out:
# 15.6    3522
# 16.1     685
# 14.0     229
# 16.0     207
# 17.3     135
# 13.0      33
# 17.0      11
# Name: Screen_Size, dtype: int64

# %%
df[df['product_info'].str.contains('in[cç]')]
# Out:
#          Brand                                       product_link  \
# 14     MONSTER  https://www.trendyol.com//monster/abra-a5-v17-...
# 25        DELL  https://www.trendyol.com//dell/inspiron-15-352...
# 76          HP  https://www.trendyol.com//hp/victus-7n9v0ea-15...
# 77          HP  https://www.trendyol.com//hp/victus-16-r0064nt...
# 102       ASUS  https://www.trendyol.com//asus/vivobook-15-12-...
# ...        ...                                                ...
# 4890  GIGABYTE  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
# 4895  GIGABYTE  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
# 4900  GIGABYTE  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
# 4905  GIGABYTE  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
# 4910  GIGABYTE  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
#
#                                            product_info  product_price  \
# 14    Abra A5 V17.3.4 Intel Core i7 11800H 32GB RAM ...          17275
# 25    Inspiron 15 3520 i5-1235U 8GB RAM 256GB SSD 15...          49499
# 76    Victus 7N9V0EA 15-FA1028NT i7-13700H 16GB 1TB ...          35499
# 77    Victus 16-R0064NT 8B5Y1EA i7-13700H 32GB 1TB R...          11099
# 102   Vivobook 15 12.Nesil Core i5 1235U-8Gb-512Gb S...          24999
# ...                                                 ...            ...
# 4890  Abra A5 V17.3.4 Intel Core i7 11800H 32GB RAM ...          17275
# 4895  Abra A5 V17.3.4 Intel Core i7 11800H 32GB RAM ...          17275
# 4900  Abra A5 V17.3.4 Intel Core i7 11800H 32GB RAM ...          17275
# 4905  Abra A5 V17.3.4 Intel Core i7 11800H 32GB RAM ...          17275
# 4910  Abra A5 V17.3.4 Intel Core i7 11800H 32GB RAM ...          17275
#
#                Processor  RAM  Storage  Screen_Size
# 14             i7 11800H   32        4         17.3
# 25              i5-1235U    8      256         15.6
# 76             i7-13700H   16        1         15.6
# 77             i7-13700H   32        1         16.1
# 102   i5 1235U-8Gb-512Gb    8      512         15.6
# ...                  ...  ...      ...          ...
# 4890           i7 11800H   32        4         17.3
# 4895           i7 11800H   32        4         17.3
# 4900           i7 11800H   32        4         17.3
# 4905           i7 11800H   32        4         17.3
# 4910           i7 11800H   32        4         17.3
#
# [119 rows x 8 columns]

# %%
#OS sütunu ekleyelim.

df['OS'] = df['product_info'].str.extract(r'(\bFree[dD]os|FreeDOS|FDOS|Fdos|Dos|DOS|Windows|[Ll]inux|LİNUX|[Ll]in|[Mm]acos|[Mm]ac|[Ww]\d\d?|[Ww]in\s?\d\d?|WPr|[Ww]in|W[Iİ]N|Ubuntu|\d\d?\s?Home)')[0]

df.sample(5)
# Out:
#        Brand                                       product_link  \
# 2737  CASPER  https://www.trendyol.com//casper/nirvana-x600-...
# 3699      HP  https://www.trendyol.com//hp/omen-16-wf0026nta...
# 760    APPLE  https://www.trendyol.com//apple/macbook-air-13...
# 1168      HP  https://www.trendyol.com//hp/15-fd0030nt-88u10...
# 3603      HP  https://www.trendyol.com//hp/victus-16-ryzen-7...
#
#                                            product_info  product_price  \
# 2737  Nirvana X600.1235-BF00X-M-F Intel Core i5-1235...          18599
# 3699  Omen 16-WF0026NTA38 Intel Core I7 13700HX 32GB...          19999
# 760                 Macbook Air 13" M1 16gb 512gb Altın          37999
# 1168  15-FD0030NT 88U10EA03 i3-N305 16GB 256SSD 15.6...          28499
# 3603  Victus 16 Ryzen 7-6800H 32GB 512GB RTX3050Ti/4...          33999
#
#           Processor  RAM  Storage  Screen_Size       OS
# 2737       i5-1235U   16        1         15.6  Freedos
# 3699     I7 13700HX   32        1         16.1  Freedos
# 760     Macbook Air   16      512         13.0      Mac
# 1168        i3-N305   16      256         15.6  FreeDOS
# 3603  Ryzen 7-6800H   32      512         16.1      W11

# %%
df.OS.isnull().sum()
# Out:
# 174

# %%
df['OS'].fillna("Windows 11", inplace= True)

# %%
df.OS.isnull().sum()
# Out:
# 0

# %%
df.OS.value_counts()
# Out:
# Freedos       1237
# W11            924
# Windows        600
# FreeDos        427
# FDOS           271
# Win11          258
# FreeDOS        181
# DOS            180
# Windows 11     174
# Dos            135
# W10             93
# Mac             85
# Fdos            74
# Ubuntu          60
# Win 11          27
# w11             17
# Linux           12
# Win10            8
# WIN              5
# WPr              4
# 11 Home          3
# Win 10           3
# 10 Home          3
# W07              3
# Win              3
# w04              2
# w8               2
# W8               2
# Win7             2
# WİN              2
# W05              2
# W6               2
# W3               1
# w56              1
# W50              1
# W03              1
# w03              1
# W14              1
# W9               1
# w01              1
# w2               1
# w5               1
# Lin              1
# W7               1
# W04              1
# W16              1
# w07              1
# win10            1
# W09              1
# w02              1
# w10              1
# W02              1
# LİNUX            1
# Name: OS, dtype: int64

# %%
valid_OS = ["FreeDOS","Windows 11", "Windows 10","MacOS","Linux" ]

# Eğer Screen_Size Freedos,FreeDos,FDOS,DOS,Dos,Fdos ise yeni değerini FreeDOS yap
df.loc[df['OS'].isin(["Freedos","FreeDos","FDOS","DOS","Dos","Fdos"]), 'OS'] = "FreeDOS"

# Eğer OS W11,Windows,Win11,Win 11,w11,WIN,11 Home ise yeni değerini Windows 11 yap
df.loc[df['OS'].isin(["W11","Windows","Win11","Win 11","w11","WIN","11 Home" ]), 'OS']= "Windows 11"

# Eğer OS W10 ise yeni değerini Windows 10 yap
df.loc[df['OS'].isin(["W10","Win10","Win 10","w10","win10" ]), 'OS'] = "Windows 10"

# Eğer OS Mac ise yeni değerini MacOS yap
df.loc[df['OS'].isin(["Mac"] ), 'OS'] = "MacOS"

# Eğer Ubuntu,Linux,Lin,LİNUX ise yeni değerini Linux yap
df.loc[df['OS'].isin(["Ubuntu","Linux","Lin","LİNUX"]), 'OS'] = "Linux"

# Eğer Screen_Size valid_OS listesinde değilse, o zaman Windows 11 yap
df.loc[~df['OS'].isin(valid_OS), 'OS'] = "Windows 11"

# %%
df.OS.value_counts()
# Out:
# FreeDOS       2505
# Windows 11    2052
# Windows 10     106
# MacOS           85
# Linux           74
# Name: OS, dtype: int64

# %%
df.Processor.value_counts()
# Out:
# i7-13700H                        390
# i5 12450H                        312
# i7-12650H                        277
# i5 12500H                        239
# I7 13700h                        225
#                                 ...
# Ryzen 7 7735HS-16GB                1
# I5 1035g1u                         1
# I7 1195g7                          1
# İ5 1135g7                          1
# Ryzen 7 Pro-14"-16G-512SD-WPr      1
# Name: Processor, Length: 514, dtype: int64

# %%
# İki boşluğu olanların ilk boşluğunu kaldır
df['Processor'] = df['Processor'].apply(lambda x: x.replace(" ", "", 1) if x.count(" ") >= 2 else x)

df['ProcessorType'] = df['Processor'].str.split('[- ]', 1, expand=True)[0]
df[ 'ProcessorModel'] = df['Processor'].str.extract(r'(\d{4}\d?\w+|\w\d{3}\d?|d{4})')[0]

# İlk sütunu büyük harfe dönüştürme (örneğin, "I5" yerine "i5" gibi)
df['ProcessorType'] = df['ProcessorType'].str.upper()
df.sample(50)
# Out:
#          Brand                                       product_link  \
# 2561    CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 3351      ASUS  https://www.trendyol.com//asus/rog-strix-g17-g...
# 1606      DELL  https://www.trendyol.com//dell/vostro-3520-i7-...
# 908     CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 1797    CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 3514        HP  https://www.trendyol.com//hp/victus-16-r0030nt...
# 4276        HP  https://www.trendyol.com//hp/255-g9-r7-5825u-6...
# 4655    CASPER  https://www.trendyol.com//casper/g870-1265-dxb...
# 4589   MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
# 369         HP  https://www.trendyol.com//hp/pavilion-plus-evo...
# 3614        HP  https://www.trendyol.com//hp/250-g9-6q8m7es04-...
# 3538    CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 3628        HP  https://www.trendyol.com//hp/victus-15-fa1028n...
# 2437    CASPER  https://www.trendyol.com//casper/g870-1265-dxb...
# 1419       MSI  https://www.trendyol.com//msi/vr-ready-raider-...
# 4135        HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 4438    LENOVO  https://www.trendyol.com//lenovo/v15-g3-i5-123...
# 2501        HP  https://www.trendyol.com//hp/victus-16-r0037nt...
# 4489        HP  https://www.trendyol.com//hp/probook-450-g9-i7...
# 4060        HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 3394      ASUS  https://www.trendyol.com//asus/rog-strix-g17-g...
# 3467    LENOVO  https://www.trendyol.com//lenovo/loq-82xv00nkt...
# 4377        HP  https://www.trendyol.com//hp/250-g9-i5-1240p-3...
# 963       DELL  https://www.trendyol.com//dell/inspiron-3520-i...
# 1810    LENOVO  https://www.trendyol.com//lenovo/legion5-intel...
# 4291        HP  https://www.trendyol.com//hp/255-g9-r7-5825u-1...
# 3588        HP  https://www.trendyol.com//hp/omen-16-wf0026nta...
# 800    MONSTER  https://www.trendyol.com//monster/semruk-s7-v9...
# 2408    CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 4514        HP  https://www.trendyol.com//hp/250-g9-intel-core...
# 393    MONSTER  https://www.trendyol.com//monster/semruk-s7-v9...
# 1907        HP  https://www.trendyol.com//hp/250-g9-i5-1235u-1...
# 2227      ASUS  https://www.trendyol.com//asus/tuf-gaming-a15-...
# 3641  GIGABYTE  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
# 3479    LENOVO  https://www.trendyol.com//lenovo/legion-5-15it...
# 338       ACER  https://www.trendyol.com//acer/aspire-3-a315-5...
# 3578        HP  https://www.trendyol.com//hp/omen-16-wf0026nta...
# 716     CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 1938  GIGABYTE  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
# 4846   MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
#
abra A5 V20.3.2 Intel Core I7 13700h 32 Gb Ram...          50199
# 1938  Abra A5 V20.4.4 Intel Core i5 12450H 16 GB RAM...          16499
# 4846  Aspire 3 AMD Ryzen 3-7320U 8GB 256GB SSD DOS 1...          11740
# 1739  Tuf Gaming F15 Fx507zc4a22-hn008a22 Intel I7 1...          70855
# 2334  Vostro 3520 i7-1255U 32 GB 1 TBSSD 15.6" FHD W...          17699
# 836   Abra A5 V20.4.4 Intel Core i5 12450H 16 GB RAM...          41297
# 3997  Victus 16 i7-13700H 32GB 2TB+2TB SSD RTX4070/8...          63326
# 2192  Tuf Gaming F15 Fx507zc4a37-hn008a37 Intel I7 1...          32049
# 3210  Excalibur G870.1265-DFA0X-B Intel Core i7-1265...          13249
# 311   Abra A5 V20.4.4 Intel Core i5 12450H 16 GB RAM...          13999
# 4528  250 G9 Intel Core I5 1235u 32gb 512gb Ssd 15,6...          21399
# 4100  Victus 16 i7-13700H 40GB 2TB+2TB SSD RTX4050/6...          53831
# 2304  Nirvana X600.1235-BX00A-K-F Intel Core i5-1235...          15299
#
#                            Processor  RAM  Storage  Screen_Size          OS  \
# 2561                       I7 13700h   32        2         15.6     FreeDOS
# 3351                   Ryzen9 7845HX   16        1         17.3  Windows 11
# 1606                        i7-1255U   24      512         15.6  Windows 11
# 908                        i7-12650H   32        1         15.6     FreeDOS
# 1797                       I7 13700h   32        2         15.6     FreeDOS
# 3514                       R0030NTi7   16        2         16.1  Windows 11
# 4276                        R7-5825U   64        1         15.6  Windows 11
# 4655                       i5 12450H   16        4         15.6     FreeDOS
# 4589                        i3-1215U    4        4         15.6     FreeDOS
# 369   i5 1340P-16Gb-512Ssd-14inc-W11   16      512         15.6  Windows 11
# 3614                        I5-1235u   16      250         15.6     FreeDOS
# 3538                       i7-12650H   32        1         15.6     FreeDOS
# 3628                       i7 13700H   32        1         15.6  Windows 11
# 2437                       i5 12500H   16      512         15.6  Windows 11
# 1419                   i9 13980HX-32   32        1         17.0  Windows 11
# 4135                       i7-13700H   24      512         16.1  Windows 11
# 4438                        i5-1235U    8      512         15.6  Windows 11
# 2501                       i7 13700H    8      512         16.1  Windows 11
# 4489                        I7-1255u   64        1         15.6  Windows 11
# 4060                       i7 13700H   48        4         16.1  Windows 11
# 3394                   Ryzen9 7845HX   64        2         17.3     FreeDOS
# 3467                       i5-12450H   64        2         15.6     FreeDOS
# 4377                        i5-1240P   32      250         15.6     FreeDOS
# 963                         i7 1255U   64        2         15.6  Windows 11
# 1810                       I7-11600h   16      256         15.6     FreeDOS
# 4291                        R7-5825U   16      512         15.6  Windows 11
# 3588                      I7 13700HX   64        4         16.1  Windows 11
# 800                       i9 13950HX   32        2         17.0     FreeDOS
# 2408                       I7 13700h   32        2         15.6     FreeDOS
# 4514                        I5 1235u   32      250         15.6  Windows 11
# 393                       i9 13950HX   64        2         17.0     FreeDOS
# 1907                        I5-1235u   16      250         15.6  Windows 11
# 2227                   Ryzen9 7940HS   32        1         15.6     FreeDOS
# 3641                       i5 12450H   16        4         15.6     FreeDOS
# 3479                       I7-11600H   32        2         15.6  Windows 10
# 338                        I5-1135g7    8      256         15.6     FreeDOS
# 3578                      I7 13700HX   32        2         16.1  Windows 11
# 716                        I7 13700h   32        2         15.6     FreeDOS
# 1938                       i5 12450H   16        4         15.6     FreeDOS
# 4846                   Ryzen 3-7320U    8      256         15.6     FreeDOS
# 1739                       I7 12700h   16        1         15.6  Windows 11
# 2334                        i7-1255U   32        1         15.6  Windows 11
# 836                        i5 12450H   16        4         15.6     FreeDOS
# 3997                       i7-13700H   32        2         16.1     FreeDOS
# 2192                       I7 12700h   32      512         15.6  Windows 10
# 3210                       i7-12650H   32        1         15.6     FreeDOS
# 311                        i5 12450H   16        4         15.6     FreeDOS
# 4528                        I5 1235u   32      250         15.6     FreeDOS
# 4100                       i7-13700H   40        2         16.1  Windows 11
# 2304                        i5-1235U   16        2         15.6  Windows 11
#
#      ProcessorType ProcessorModel
# 2561            I7         13700h
# 3351        RYZEN9         7845HX
# 1606            I7          1255U
# 908             I7         12650H
# 1797            I7         13700h
# 3514     R0030NTI7          R0030
# 4276            R7          5825U
# 4655            I5         12450H
# 4589            I3          1215U
# 369             I5          1340P
# 3614            I5          1235u
# 3538            I7         12650H
# 3628            I7         13700H
# 2437            I5         12500H
# 1419            I9        13980HX
# 4135            I7         13700H
# 4438            I5          1235U
# 2501            I7         13700H
# 4489            I7          1255u
# 4060            I7         13700H
# 3394        RYZEN9         7845HX
# 3467            I5         12450H
# 4377            I5          1240P
# 963             I7          1255U
# 1810            I7         11600h
# 4291            R7          5825U
# 3588            I7        13700HX
# 800             I9        13950HX
# 2408            I7         13700h
# 4514            I5          1235u
# 393             I9        13950HX
# 1907            I5          1235u
# 2227        RYZEN9         7940HS
# 3641            I5         12450H
# 3479            I7         11600H
# 338             I5         1135g7
# 3578            I7        13700HX
# 716             I7         13700h
# 1938            I5         12450H
# 4846         RYZEN          7320U
# 1739            I7         12700h
# 2334            I7          1255U
# 836             I5         12450H
# 3997            I7         13700H
# 2192            I7         12700h
# 3210            I7         12650H
# 311             I5         12450H
# 4528            I5          1235u
# 4100            I7         13700H
# 2304            I5          1235U

# %%
df.ProcessorModel.isnull().sum()
# Out:
# 109

# %%
df[df.ProcessorModel.isnull()].sample(60)
# Out:
#         Brand                                       product_link  \
# 4730   CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 3722    APPLE  https://www.trendyol.com//apple/macbook-air-m2...
# 4769   CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 1036    APPLE  https://www.trendyol.com//apple/macbook-air-13...
# 409    HUAWEI  https://www.trendyol.com//huawei/huawei-matebo...
# 834     APPLE  https://www.trendyol.com//apple/macbook-pro-z1...
# 1859       HP  https://www.trendyol.com//hp/pro-x360-435-g10-...
# 1812    APPLE  https://www.trendyol.com//apple/macbook-pro-m1...
# 1424     ASUS  https://www.trendyol.com//asus/x415ma-ek741w-i...
# 2742    APPLE  https://www.trendyol.com//apple/macbook-air-m2...
# 98      APPLE  https://www.trendyol.com//apple/macbook-pro-16...
# 52      APPLE  https://www.trendyol.com//apple/macbook-air-13...
# 980     APPLE  https://www.trendyol.com//apple/15-inch-macboo...
# 6       APPLE  https://www.trendyol.com//apple/macbook-air-m1...
# 4427       HP  https://www.trendyol.com//hp/elitebook-645-g10...
# 504    CASPER  https://www.trendyol.com//casper/g870-1265-dxb...
# 1940   LENOVO  https://www.trendyol.com//lenovo/1115g4-core-i...
# 973       MSI  https://www.trendyol.com//msi/katana-17-b13vfk...
# 4898  MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
# 1301    APPLE  https://www.trendyol.com//apple/macbook-air-13...
# 2196    APPLE  https://www.trendyol.com//apple/macbook-pro-mn...
# 4753   CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 4893  MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
# 4739   CASPER  https://www.trendyol.com//casper/excalibur-g87...
#
Macbook Air M1 Çip 8gb 256gb Ssd Macos 13" Qhd...          26999
#
#                           Processor  RAM  Storage  Screen_Size          OS  \
# 4730                    Macbook Air    8      256         13.0       MacOS
# 3722                    Macbook Air   16      256         15.6       MacOS
# 4769                    Macbook Air    8      256         13.0       MacOS
# 1036                    Macbook Air    8      512         15.6       MacOS
# 409                    I5 8gb/512gb    8      512         16.0  Windows 11
# 834                     Macbook Pro   16      256         15.6       MacOS
# 1859  Ryzen 5-13.3"-16GB-512SSD-WPr   16      512         15.6  Windows 11
# 1812                    Macbook Pro   16      512         15.6       MacOS
# 1424                      Celeron 4    4        4         15.6  Windows 11
# 2742                    Macbook Air    8      512         15.6       MacOS
# 98                      MacBook Pro   32        1         15.6       MacOS
# 52                      Macbook Air    8      256         15.6       MacOS
# 980                     MacBook Air  512      512         15.6       MacOS
# 6                       Macbook Air    8      256         13.0       MacOS
# 4427   Ryzen7 Pro-14"-16G-512SD-WPr   16      512         14.0  Windows 11
# 504                     Macbook Air    8      512         15.6       MacOS
# 1940                         i3 1TB  256        1         15.6  Windows 11
# 973                         i9 32GB   32        1         15.6  Windows 11
# 4898                    Macbook Air    8      256         13.0       MacOS
# 1301                    Macbook Air    8      512         15.6       MacOS
# 2196                    Macbook Pro    8      256         15.6       MacOS
# 4753                    Macbook Air    8      256         13.0       MacOS
# 4893                    Macbook Air    8      256         13.0       MacOS
# 4739                    Macbook Air    8      256         13.0       MacOS
# 454                     MacBook Pro   16      512         15.6       MacOS
# 1346                    Macbook Pro   16      256         15.6       MacOS
# 4801                    Macbook Air    8      256         13.0       MacOS
# 4746                    Macbook Air    8      256         13.0       MacOS
# 548                            R5-5    8      512         15.6  Windows 11
# 474                         i7 7Y75    8      256         15.6  Windows 11
# 576                          I3 8gb    8      256         15.6  Windows 11
# 599                     Macbook Pro   36        1         14.0       MacOS
# 4908                    Macbook Air    8      256         13.0       MacOS
# 47                Celeron İşlemci/4    4        4         15.6  Windows 11
# 4775                    Macbook Air    8      256         13.0       MacOS
# 260                     Macbook Air  512      512         13.0       MacOS
# 443                        i9 Yeşil   32        1         15.6  Windows 11
# 3313                    Macbook Pro   18      512         16.0       MacOS
# 326                        I5 8/512  512      512         15.6  Windows 11
# 1393     Ryzen5 -14''-8G-512SSD-Dos    8      512         15.6     FreeDOS
# 2079                    Macbook Air    8      512         15.6       MacOS
# 456                     Macbook Pro    8      256         15.6       MacOS
# 4690                    Macbook Air    8      256         13.0       MacOS
# 797                  Ryzen7 7.Nesil   16      512         14.0  Windows 11
# 410                          Corei7   16      512         15.6     FreeDOS
# 1935                    Macbook Pro   18      512         14.0       MacOS
# 41                      Macbook Air    8      256         15.6       MacOS
# 1177                    Macbook Pro   16      512         13.0       MacOS
# 753                          Corei7   16      512         15.6     FreeDOS
# 655                     Macbook Air   16      256         15.6       MacOS
# 282                     Macbook Air   16      256         15.6       MacOS
# 1302                    MacBook Pro   16        1         15.6       MacOS
# 948                     Macbook Pro    8      512         15.6       MacOS
# 2078                    MacBook Pro   16        1         15.6       MacOS
# 728                     Macbook Pro   16      256         13.0       MacOS
# 2303                    Macbook Pro   16        1         16.0       MacOS
# 653                     MacBook Air   16      512         15.6       MacOS
# 768                     i7 16GB-1TB   16        1         15.6  Windows 11
# 1034                    Macbook Air   16      256         15.6       MacOS
# 4724                    Macbook Air    8      256         13.0       MacOS
#
#      ProcessorType ProcessorModel
# 4730       MACBOOK            NaN
# 3722       MACBOOK            NaN
# 4769       MACBOOK            NaN
# 1036       MACBOOK            NaN
# 409             I5            NaN
# 834        MACBOOK            NaN
# 1859         RYZEN            NaN
# 1812       MACBOOK            NaN
# 1424       CELERON            NaN
# 2742       MACBOOK            NaN
# 98         MACBOOK            NaN
# 52         MACBOOK            NaN
# 980        MACBOOK            NaN
# 6          MACBOOK            NaN
# 4427        RYZEN7            NaN
# 504        MACBOOK            NaN
# 1940            I3            NaN
# 973             I9            NaN
# 4898       MACBOOK            NaN
# 1301       MACBOOK            NaN
# 2196       MACBOOK            NaN
# 4753       MACBOOK            NaN
# 4893       MACBOOK            NaN
# 4739       MACBOOK            NaN
# 454        MACBOOK            NaN
# 1346       MACBOOK            NaN
# 4801       MACBOOK            NaN
# 4746       MACBOOK            NaN
# 548             R5            NaN
# 474             I7            NaN
# 576             I3            NaN
# 599        MACBOOK            NaN
# 4908       MACBOOK            NaN
# 47         CELERON            NaN
# 4775       MACBOOK            NaN
# 260        MACBOOK            NaN
# 443             I9            NaN
# 3313       MACBOOK            NaN
# 326             I5            NaN
# 1393        RYZEN5            NaN
# 2079       MACBOOK            NaN
# 456        MACBOOK            NaN
# 4690       MACBOOK            NaN
# 797         RYZEN7            NaN
# 410         COREI7            NaN
# 1935       MACBOOK            NaN
# 41         MACBOOK            NaN
# 1177       MACBOOK            NaN
# 753         COREI7            NaN
# 655        MACBOOK            NaN
# 282        MACBOOK            NaN
# 1302       MACBOOK            NaN
# 948        MACBOOK            NaN
# 2078       MACBOOK            NaN
# 728        MACBOOK            NaN
# 2303       MACBOOK            NaN
# 653        MACBOOK            NaN
# 768             I7            NaN
# 1034       MACBOOK            NaN
# 4724       MACBOOK            NaN

# %%
# Eğer ProcessorModel R0030NTi7 ise yeni değerini 13 yap
df.loc[df['ProcessorModel'].isin(["R0030"] ), 'ProcessorModel'] = "13"

# ProcessorModel sütunu NaN olan satırları bulun
nan_rows = df[df['ProcessorModel'].isna()]

# product_link sütununu kontrol ederek ProcessorModel sütununu güncelleyin
for index, row in nan_rows.iterrows():
    if 'mac' in row['product_link'].lower():
        df.at[index, 'ProcessorModel'] = "2"   #bunun yerine None yazılabilirdi ama int yapmak için yazdık
    else:
        df.at[index, 'ProcessorModel'] = "13"
        
# burada macbook olanlara karar verilmeli genelde 2. nesil ama macbookun 2. nesli ile intel aynı değil

# %%
# Kalan null değerleri 11 ile doldur.
#df['ProcessorModel'].fillna("11", inplace= True)

# %%
df.ProcessorModel.isnull().sum()
# Out:
# 0

# %%
# Generation sütununu oluşturma
df['ProcessorGeneration'] = df['ProcessorModel'].apply(lambda x: 
    int(x[1]) if x and x[0].isdigit() == False and len(x) > 1 and x[1].isdigit() 
    else int(x[:2]) if x and x[:2].isdigit() and int(x[:2]) < 15 
    else int(x[0]) if x and x[:2].isdigit() and int(x[:2]) > 15 
    else None
)

# %%
df.sample(45)
# Out:
#            Brand                                       product_link  \
# 2801        ACER  https://www.trendyol.com//acer/aspire-3-a315-5...
# 3592          HP  https://www.trendyol.com//hp/omen-16-wf0026nta...
# 3451          HP  https://www.trendyol.com//hp/victus-15-fb0017n...
# 4570      CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 3681      CASPER  https://www.trendyol.com//casper/g870-1265-dxb...
# 3657          HP  https://www.trendyol.com//hp/victus-15-fa1028n...
# 2953        DELL  https://www.trendyol.com//dell/inspiron-3520-i...
# 2215  GPTURKGRUP  https://www.trendyol.com//gpturkgrup/hp-250-g9...
# 1864      LENOVO  https://www.trendyol.com//lenovo/thinkbook-15-...
# 3227      LENOVO  https://www.trendyol.com//lenovo/v15-g3-intel-...
# 527       CASPER  https://www.trendyol.com//casper/g870-1265-dxb...
# 1939          HP  https://www.trendyol.com//hp/victus-16-s0051nt...
# 1439      LENOVO  https://www.trendyol.com//lenovo/thinkbook-15-...
# 1361        ASUS  https://www.trendyol.com//asus/vivobook-15-x15...
# 4271      LENOVO  https://www.trendyol.com//lenovo/thinkpad-t16-...
# 3636          HP  https://www.trendyol.com//hp/victus-15-fa1028n...
# 4523      CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 4824     MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
# 1101      CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 3893          HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 1153      CASPER  https://www.trendyol.com//casper/nirvana-x600-...
# 128          MSI  https://www.trendyol.com//msi/bravo-17-d7vf-06...
# 1891      CASPER  https://www.trendyol.com//casper/g870-1265-dxb...
# 3106      LENOVO  https://www.trendyol.com//lenovo/v15-g2-itl-co...
# 3463      LENOVO  https://www.trendyol.com//lenovo/loq-82xv00nkt...
# 2282      LENOVO  https://www.trendyol.com//lenovo/v15-g3-i5-123...
# 1446        ASUS  https://www.trendyol.com//asus/vivobook-15-x15...
# 3085        DELL  https://www.trendyol.com//dell/vostro-5510-i5-...
# 4446    GIGABYTE  https://www.trendyol.com//gigabyte/g5-mf-i5-12...
# 3432      LENOVO  https://www.trendyol.com//lenovo/ip-gaming-3-i...
# 3382        ASUS  https://www.trendyol.com//asus/rog-strix-g17-g...
# 4357          HP  https://www.trendyol.com//hp/250-g9-i5-1240p-1...
# 4255          HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 1334          HP  https://www.trendyol.com//hp/victus-gaming-16-...
# 3995          HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 969       LENOVO  https://www.trendyol.com//lenovo/thinkpad-e14-...
# 4066          HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 2271      LENOVO  https://www.trendyol.com//lenovo/ideapad-gamin...
# 2134          HP  https://www.trendyol.com//hp/15-80r51ea01-cele...
# 2977      LENOVO  https://www.trendyol.com//lenovo/e15-i5-1235u-...
# 4165          HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 3516      CASPER  https://www.trendyol.com//casper/excalibur-g87...
# 341       LENOVO  https://www.trendyol.com//lenovo/ip-gaming3-am...
# 3986          HP  https://www.trendyol.com//hp/victus-16-i7-1370...
# 4060          HP  https://www.trendyol.com//hp/victus-16-i7-1370...
#
#                                            product_info  product_price  \
# 2801  Aspire 3 A315-58-36YJ I3-1115G4 12gb Ram 512SS...          20000
# 3592  Omen 16-WF0026NTA45 Intel Core I7 13700HX 64GB...          29999
# 3451  Victus 15-FB0017NT 7N5R1EA07 Ryzen5 5600H 64GB...          31699
# 4570  Excalibur G870.1265-DFA0X-B Intel Core i7-1265...
Excalibur G870.1265-DFA0X-B Intel Core i7-1265...          98218
# 341   IP Gaming3 AMD Ryzen 5-7535HS 16GB 512GB RTX40...          25999
# 3986  Victus 16 i7-13700H 48GB 2TB+2TB SSD RTX4070/8...          63186
# 4060  Victus 16 i7 13700H 48GB 4TB SSD RTX4060/8GB 1...          61034
#
#            Processor  RAM  Storage  Screen_Size          OS ProcessorType  \
# 2801       I3-1115G4   12      512         15.6  Windows 11            I3
# 3592      I7 13700HX   64      512         16.1  Windows 11            I7
# 3451    Ryzen5 5600H   64        1         15.6  Windows 11        RYZEN5
# 4570       i7-12650H   32        1         15.6     FreeDOS            I7
# 3681       i5 12500H   16      512         15.6  Windows 11            I5
# 3657       i7 13700H   64        1         15.6  Windows 11            I7
# 2953        i7 1255U   16        2         15.6       Linux            I7
# 2215        I5-1235U    8      250         15.6     FreeDOS            I5
# 1864        R7-5700U   16      512         15.6     FreeDOS            R7
# 3227        I7-1255U   16        1         15.6  Windows 11            I7
# 527        i5 12500H   16      512         15.6  Windows 11            I5
# 1939   Ryzen7 7840HS    6        1         16.1  Windows 11        RYZEN7
# 1439    Ryzen7 5825u   16      512         15.6     FreeDOS        RYZEN7
# 1361        i5 1235U   16        1         15.6  Windows 11            I5
# 4271        i7-1260P   32        1         16.0  Windows 11            I7
# 3636       i7 13700H   16        2         15.6  Windows 11            I7
# 4523       I7 13700h   32        2         15.6     FreeDOS            I7
# 4824   Ryzen 3-7320U    8      256         15.6     FreeDOS         RYZEN
# 1101       i7-12650H   32        1         15.6     FreeDOS            I7
# 3893       i7-13700H   16      256         16.1     FreeDOS            I7
# 1153        i5-1235U    8      500         15.6  Windows 11            I5
# 128        R7-7735HS   16        1         17.3     FreeDOS            R7
# 1891       i5 12500H   16      512         15.6  Windows 11            I5
# 3106       I7-1165g7    8      500         15.6     FreeDOS            I7
# 3463       i5-12450H   64      512         15.6     FreeDOS            I5
# 2282        I5-1235U   16      512         15.6  Windows 11            I5
# 1446        i3-1215U   20        1         15.6     FreeDOS            I3
# 3085       I5-11300h   20      512         15.6  Windows 11            I5
# 4446       i5 12450H   16        4         15.6     FreeDOS            I5
# 3432       I5 10300h   64        1         15.6  Windows 11            I5
# 3382   Ryzen9 7845HX   64        1         17.3  Windows 11        RYZEN9
# 4357        i5-1240P   16      250         15.6     FreeDOS            I5
# 4255       i7-13700H   64        2         16.1     FreeDOS            I7
# 1334    Ryzen7 5800H   16        1         16.1  Windows 11        RYZEN7
# 3995       i7 13700H   32        4         16.1     FreeDOS            I7
# 969         I5-1235u   16      512         14.0  Windows 11            I5
# 4066       i7-13700H   16        2         16.1     FreeDOS            I7
# 2271   Ryzen5 7535HS   16        1         15.6     FreeDOS        RYZEN5
# 2134    Celeron N200    8      128         15.6  Windows 11       CELERON
# 2977        I5-1235u   24        1         15.6  Windows 11            I5
# 4165       i7-13700H   24        2         16.1     FreeDOS            I7
# 3516       i7-12650H   32        1         15.6     FreeDOS            I7
# 341   Ryzen 5-7535HS   16      512         15.6     FreeDOS         RYZEN
# 3986       i7-13700H   48        2         16.1  Windows 11            I7
# 4060       i7 13700H   48        4         16.1  Windows 11            I7
#
#      ProcessorModel  ProcessorGeneration
# 2801         1115G4                   11
# 3592        13700HX                   13
# 3451          5600H                    5
# 4570         12650H                   12
# 3681         12500H                   12
# 3657         13700H                   13
# 2953          1255U                   12
# 2215          1235U                   12
# 1864          5700U                    5
# 3227          1255U                   12
# 527          12500H                   12
# 1939         7840HS                    7
# 1439          5825u                    5
# 1361          1235U                   12
# 4271          1260P                   12
# 3636         13700H                   13
# 4523         13700h                   13
# 4824          7320U                    7
# 1101         12650H                   12
# 3893         13700H                   13
# 1153          1235U                   12
# 128          7735HS                    7
# 1891         12500H                   12
# 3106         1165g7                   11
# 3463         12450H                   12
# 2282          1235U                   12
# 1446          1215U                   12
# 3085         11300h                   11
# 4446         12450H                   12
# 3432         10300h                   10
# 3382         7845HX                    7
# 4357          1240P                   12
# 4255         13700H                   13
# 1334          5800H                    5
# 3995         13700H                   13
# 969           1235u                   12
# 4066         13700H                   13
# 2271         7535HS                    7
# 2134           N200                    2
# 2977          1235u                   12
# 4165         13700H                   13
# 3516         12650H                   12
# 341          7535HS                    7
# 3986         13700H                   13
# 4060         13700H                   13

# %%
df[df.Processor.str.contains("Ryz")]
# Out:
#         Brand                                       product_link  \
# 8      LENOVO  https://www.trendyol.com//lenovo/ideapad-amd-r...
# 10     CASPER  https://www.trendyol.com//casper/nirvana-x600-...
# 17         HP  https://www.trendyol.com//hp/pavilion-15-eh301...
# 21       ACER  https://www.trendyol.com//acer/aspire-3-amd-ry...
# 28     LENOVO  https://www.trendyol.com//lenovo/ip-gaming-3-a...
# ...       ...                                                ...
# 4867  MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
# 4868  MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
# 4869  MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
# 4870  MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
# 4876   LENOVO  https://www.trendyol.com//lenovo/ideapad-3-int...
#
#                                            product_info  product_price  \
# 8     Ideapad AMD Ryzen 7 5700U 16GB 512GB SSD Freed...          37999
# 10    Nirvana X600.5700-BF00X-G-F AMD Ryzen 7-5700U ...           8779
# 17    Pavilion 15-EH3011NT AMD Ryzen 5-7530U 8GB 512...          32283
# 21    Aspire 3 AMD Ryzen 3-7320U 8GB 256GB SSD DOS 1...           9444
# 28    IP Gaming 3 AMD Ryzen 5-6600H 16GB 512GB RTX30...          14799
# ...                                                 ...            ...
# 4867  Aspire 3 AMD Ryzen 3-7320U 8GB 256GB SSD DOS 1...          11740
# 4868  Aspire 3 AMD Ryzen 3-7320U 8GB 256GB SSD DOS 1...          11740
# 4869  Aspire 3 AMD Ryzen 3-7320U 8GB 256GB SSD DOS 1...          11740
# 4870  Aspire 3 AMD Ryzen 3-7320U 8GB 256GB SSD DOS 1...          11740
# 4876  Aspire 3 AMD Ryzen 3-7320U 8GB 256GB SSD DOS 1...          11740
#
#           Processor  RAM  Storage  Screen_Size          OS ProcessorType  \
# 8      Ryzen7 5700U   16      512         15.6     FreeDOS        RYZEN7
# 10    Ryzen 7-5700U   16        1         15.6     FreeDOS         RYZEN
# 17    Ryzen 5-7530U    8      512         15.6     FreeDOS         RYZEN
# 21    Ryzen 3-7320U    8      256         15.6     FreeDOS         RYZEN
# 28    Ryzen 5-6600H   16      512         16.0  Windows 11         RYZEN
# ...             ...  ...      ...          ...         ...           ...
# 4867  Ryzen 3-7320U    8      256         15.6     FreeDOS         RYZEN
# 4868  Ryzen 3-7320U    8      256         15.6     FreeDOS         RYZEN
# 4869  Ryzen 3-7320U    8      256         15.6     FreeDOS         RYZEN
# 4870  Ryzen 3-7320U    8      256         15.6     FreeDOS         RYZEN
# 4876  Ryzen 3-7320U    8      256         15.6     FreeDOS         RYZEN
#
#      ProcessorModel  ProcessorGeneration
# 8             5700U                    5
# 10            5700U                    5
# 17            7530U                    7
# 21            7320U                    7
# 28            6600H                    6
# ...             ...                  ...
# 4867          7320U                    7
# 4868          7320U                    7
# 4869          7320U                    7
# 4870          7320U                    7
# 4876          7320U                    7
#
# [626 rows x 12 columns]

# %%
df.ProcessorGeneration.isnull().sum()
# Out:
# 0

# %%
df.ProcessorGeneration = df.ProcessorGeneration.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4822 entries, 0 to 4940
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand
Abra A5 V20.4.4 Intel Core i5 12450H 16 GB RAM...          59999
# 1398  Abra A5 V20.4.4 Intel Core i5 12450H 16 GB RAM...          60345
# 3611  Omen Gaming Laptop 16-k0010nt I7-12700h 16gb 1...          20537
# 1183  Abra A5 V21.2.1 Intel Core i5 12450H 16 GB RAM...          15999
# 1592  Abra A5 V20.4.4 Intel Core i5 12450H 16 GB RAM...          23299
# 278   7P648EA Victus 16-R0053NT i5-13500H 16G Ram 6G...          37999
#
#           Processor  RAM  Storage  Screen_Size          OS ProcessorType  \
# 1547       I5 1335U   32      250         15.6  Windows 11            I5
# 1535   RYZEN7-5700U   12      512         17.3     FreeDOS        RYZEN7
# 3153       I7-1255u    8      512         14.0  Windows 11            I7
# 4748      i7 11800H   32        4         17.3     FreeDOS            I7
# 4716      i7-12650H   32        2         15.6     FreeDOS            I7
# 1935    Macbook Pro   18      512         14.0       MacOS       MACBOOK
# 4902      I5-1135G7    8      256         15.6     FreeDOS            I5
# 2432      R9 7940HS   16      512         15.6     FreeDOS            R9
# 1151      I5 1135g7   12      256         15.6     FreeDOS            I5
# 2228       i5-1235U   16        1         15.6     FreeDOS            I5
# 1991       i7-1365U   32        2         14.0  Windows 11            I7
# 4763  Ryzen 3-7320U    8      256         15.6     FreeDOS         RYZEN
# 3948      i7-13700H   32        1         16.1  Windows 11            I7
# 327        I7-1255u   16      512         15.6     FreeDOS            I7
# 3874      i7-13700H   16      256         16.1  Windows 11            I7
# 1166     I5 1035g1u    8      512         15.6  Windows 11            I5
# 4496      I5-1135g7   64        1         14.0  Windows 10            I5
# 2302   Ryzen5 7520u    8      512         15.6     FreeDOS        RYZEN5
# 2639     i7 13650HX   64        1         15.6  Windows 11            I7
# 4576      i7-12650H   32        1         15.6     FreeDOS            I7
# 588        i5 1235U    8      512         15.6     FreeDOS            I5
# 3105      I7 13700h   32        2         15.6     FreeDOS            I7
# 4768      I5-1135G7    8      256         15.6     FreeDOS            I5
# 3459      I5-12450h   32        1         15.6  Windows 11            I5
# 2589      i5 12500H   16      512         15.6  Windows 11            I5
# 2162   Ryzen7 5800h   16      512         15.6     FreeDOS        RYZEN7
# 474         i7 7Y75    8      256         15.6  Windows 11            I7
# 587   Celeron N4020    4        4         14.0     FreeDOS       CELERON
# 2640      I5-12450h   32        1         15.6     FreeDOS            I5
# 2466       i5-1235U    8      512         14.0     FreeDOS            I5
# 3402   Ryzen7 6800h   16        1         16.0  Windows 11        RYZEN7
# 3973      i7-13700H    8        1         16.1  Windows 11            I7
# 133        i7-1255U   32        1         15.6     FreeDOS            I7
# 4691      i7-12650H   32        2         15.6     FreeDOS            I7
# 3427      I7 13700H   32        2         16.1  Windows 11            I7
# 1104    Macbook Pro    8      512         14.0       MacOS       MACBOOK
# 1071      i3 1115G4    4        4         14.0     FreeDOS            I3
# 367       I5-12450H    8        4         15.6     FreeDOS            I5
# 3164      I7 1165g7    8        2         14.0  Windows 10            I7
# 4639      i5 12450H   16        4         15.6     FreeDOS            I5
# 1398      i5 12450H   16        4         15.6     FreeDOS            I5
# 3611      I7-12700h   16        1         16.1     FreeDOS            I7
# 1183      i5 12450H   16        2         15.6  Windows 11            I5
# 1592      i5 12450H   16        4         15.6     FreeDOS            I5
# 278       i5-13500H   16      512         16.1     FreeDOS            I5
#
#       ProcessorGeneration
# 1547                   13
# 1535                    5
# 3153                   12
# 4748                   11
# 4716                   12
# 1935                    2
# 4902                   11
# 2432                    7
# 1151                   11
# 2228                   12
# 1991                   13
# 4763                    7
# 3948                   13
# 327                    12
# 3874                   13
# 1166                   10
# 4496                   11
# 2302                    7
# 2639                   13
# 4576                   12
# 588                    12
# 3105                   13
# 4768                   11
# 3459                   12
# 2589                   12
# 2162                    5
# 474                    13
# 587                     4
# 2640                   12
# 2466                   12
# 3402                    6
# 3973                   13
# 133                    12
# 4691                   12
# 3427                   13
# 1104                    2
# 1071                   11
# 367                    12
# 3164                   11
# 4639                   12
# 1398                   12
# 3611                   12
# 1183                   12
# 1592                   12
# 278                    13

# %%
df[df.OS.str.contains("Mac")]
# Out:
#         Brand                                       product_link  \
# 6       APPLE  https://www.trendyol.com//apple/macbook-air-m1...
# 36      APPLE  https://www.trendyol.com//apple/macbook-pro-13...
# 39      APPLE  https://www.trendyol.com//apple/macbook-air-13...
# 41      APPLE  https://www.trendyol.com//apple/macbook-air-13...
# 52      APPLE  https://www.trendyol.com//apple/macbook-air-13...
# ...       ...                                                ...
# 4888  MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
# 4893  MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
# 4898  MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
# 4903  MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
# 4908  MONSTER  https://www.trendyol.com//monster/abra-a5-v20-...
#
#                                            product_info  product_price  \
# 6     Macbook Air M1 Çip 8gb 256gb Ssd Macos 13" Qhd...          29999
# 36    Macbook Pro 13.3 Inç M2 Çip 8cpu 10gpu 8gb 256...          10299
# 39       Macbook Air 13.6" M2 8gb 256gb Ssd Gece Yarısı          34899
# 41        Macbook Air 13.6" M2 8gb 256gb Ssd Uzay Grisi          34299
# 52              Macbook Air 13'' M1 8gb 256gb Ssd Gümüş          28986
# ...                                                 ...            ...
# 4888  Macbook Air M1 Çip 8gb 256gb Ssd Macos 13" Qhd...          26999
# 4893  Macbook Air M1 Çip 8gb 256gb Ssd Macos 13" Qhd...          26999
# 4898  Macbook Air M1 Çip 8gb 256gb Ssd Macos 13" Qhd...          26999
# 4903  Macbook Air M1 Çip 8gb 256gb Ssd Macos 13" Qhd...          26999
# 4908  Macbook Air M1 Çip 8gb 256gb Ssd Macos 13" Qhd...          26999
#
#         Processor  RAM  Storage  Screen_Size     OS ProcessorType  \
# 6     Macbook Air    8      256         13.0  MacOS       MACBOOK
# 36    Macbook Pro    8      256         15.6  MacOS       MACBOOK
# 39    Macbook Air    8      256         15.6  MacOS       MACBOOK
# 41    Macbook Air    8      256         15.6  MacOS       MACBOOK
# 52    Macbook Air    8      256         15.6  MacOS       MACBOOK
# ...           ...  ...      ...          ...    ...           ...
# 4888  Macbook Air    8      256         13.0  MacOS       MACBOOK
# 4893  Macbook Air    8      256         13.0  MacOS       MACBOOK
# 4898  Macbook Air    8      256         13.0  MacOS       MACBOOK
# 4903  Macbook Air    8      256         13.0  MacOS       MACBOOK
# 4908  Macbook Air    8      256         13.0  MacOS       MACBOOK
#
#       ProcessorGeneration
# 6                       2
# 36                      2
# 39                      2
# 41                      2
# 52                      2
# ...                   ...
# 4888                   13
# 4893                   13
# 4898                   13
# 4903                   13
# 4908                   13
#
# [85 rows x 11 columns]
