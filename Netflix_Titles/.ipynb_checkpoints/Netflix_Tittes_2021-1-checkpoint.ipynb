# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("netflix_titles_2021.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe().T
# Out:
#                count         mean       std     min     25%     50%     75%  \
# release_year  8807.0  2014.180198  8.819312  1925.0  2013.0  2017.0  2019.0
#
#                  max
# release_year  2021.0

# %%
df.describe(include="all")
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# director        2634
# country          831
# cast             825
# date_added        10
# rating             4
# duration           3
# show_id            0
# type               0
# title              0
# release_year       0
# listed_in          0
# description        0
# dtype: int64

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.sample()
# Out:
#      show_id     type       title director  \
# 3970   s3971  TV Show  Versailles      NaN
#
#                                                    cast         country  \
# 3970  George Blagden, Alexander Vlahos, Tygh Runyan,...  France, Canada
#
#           date_added  release_year rating   duration  \
# 3970  March 29, 2019          2018  TV-MA  3 Seasons
#
#                               listed_in  \
# 3970  International TV Shows, TV Dramas
#
#                                             description
# 3970  King Louis XIV of France commissions a lavish ...

# %%
df.show_id = df.show_id.str.lstrip("s").astype(int) #rstrip() sondaki veriyi siler.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   int32
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int32(1), int64(1), object(10)
# memory usage: 791.4+ KB

# %%
df.dtypes
# Out:
# show_id          int32
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.type.unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df.type.value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
df.type.value_counts(normalize=True)
# Out:
# Movie      0.696151
# TV Show    0.303849
# Name: type, dtype: float64

# %%
df.listed_in.unique()
# Out:
# array(['Documentaries', 'International TV Shows, TV Dramas, TV Mysteries',
#        'Crime TV Shows, International TV Shows, TV Action & Adventure',
#        'Docuseries, Reality TV',
#        'International TV Shows, Romantic TV Shows, TV Comedies',
#        'TV Dramas, TV Horror, TV Mysteries', 'Children & Family Movies',
#        'Dramas, Independent Movies, International Movies',
#        'British TV Shows, Reality TV', 'Comedies, Dramas',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'Dramas, International Movies',
#        'Children & Family Movies, Comedies',
#        'British TV Shows, Crime TV Shows, Docuseries',
#        'TV Comedies, TV Dramas', 'Documentaries, International Movies',
#        'Crime TV Shows, Spanish-Language TV Shows, TV Dramas',
#        'Thrillers',
#        'International TV Shows, Spanish-Language TV Shows, TV Action & Adventure',
#        'International TV Shows, TV Action & Adventure, TV Dramas',
# ...

# %%
df.country.value_counts()
# Out:
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 748, dtype: int64

# %%
df1=df.copy()
df1.head(1)
# Out:
#    show_id   type                 title         director cast        country  \
# 0        1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description
# 0  As her father nears the end of his life, filmm...

# %%
df1.columns=df1.columns.str.upper()

# %%
df1.head(1)
# Out:
#    SHOW_ID   TYPE                 TITLE         DIRECTOR CAST        COUNTRY  \
# 0        1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            DATE_ADDED  RELEASE_YEAR RATING DURATION      LISTED_IN  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          DESCRIPTION
# 0  As her father nears the end of his life, filmm...

# %% [markdown]
# df["date_added"] = pd.to_datetime(df["date_added"])

# %%
df1.rename(columns={'DURATION' : 'DURATION(MIN)'})
# Out:
#       SHOW_ID     TYPE                  TITLE         DIRECTOR  \
# 0           1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           2  TV Show          Blood & Water              NaN
# 2           3  TV Show              Ganglands  Julien Leclercq
# 3           4  TV Show  Jailbirds New Orleans              NaN
# 4           5  TV Show           Kota Factory              NaN
# ...       ...      ...                    ...              ...
# 8802     8803    Movie                 Zodiac    David Fincher
# 8803     8804  TV Show            Zombie Dumb              NaN
# 8804     8805    Movie             Zombieland  Ruben Fleischer
# 8805     8806    Movie                   Zoom     Peter Hewitt
# 8806     8807    Movie                 Zubaan      Mozez Singh
#
#                                                    CAST        COUNTRY  \
# 0                                                   NaN  United States
# ...

# %%
import datetime
df["date_added"] = pd.to_datetime(df["date_added"])

# %%
df
# Out:
#       show_id     type                  title         director  \
# 0           1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           2  TV Show          Blood & Water              NaN
# 2           3  TV Show              Ganglands  Julien Leclercq
# 3           4  TV Show  Jailbirds New Orleans              NaN
# 4           5  TV Show           Kota Factory              NaN
# ...       ...      ...                    ...              ...
# 8802     8803    Movie                 Zodiac    David Fincher
# 8803     8804  TV Show            Zombie Dumb              NaN
# 8804     8805    Movie             Zombieland  Ruben Fleischer
# 8805     8806    Movie                   Zoom     Peter Hewitt
# 8806     8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
df.dtypes
# Out:
# show_id                  int32
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
df.set_index("show_id", drop=True)
# Out:
#             type                  title         director  \
# show_id
# 1          Movie   Dick Johnson Is Dead  Kirsten Johnson
# 2        TV Show          Blood & Water              NaN
# 3        TV Show              Ganglands  Julien Leclercq
# 4        TV Show  Jailbirds New Orleans              NaN
# 5        TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# 8803       Movie                 Zodiac    David Fincher
# 8804     TV Show            Zombie Dumb              NaN
# 8805       Movie             Zombieland  Ruben Fleischer
# 8806       Movie                   Zoom     Peter Hewitt
# 8807       Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# 1                                                      NaN  United States
# 2        Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.country.value_counts().sort_values( ascending=False).head(10)
# Out:
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: country, dtype: int64

# %%
country_new = df.country.str.split(', ', expand = True).stack()
country_new
# Out:
# 0     0    United States
# 1     0     South Africa
# 4     0            India
# 7     0    United States
#       1            Ghana
#                ...
# 8801  1           Jordan
# 8802  0    United States
# 8804  0    United States
# 8805  0    United States
# 8806  0            India
# Length: 10014, dtype: object

# %%
country_new.value_counts()
# Out:
# United States     3689
# India             1046
# United Kingdom     804
# Canada             445
# France             393
#                   ...
# Bermuda              1
# Ecuador              1
# Armenia              1
# Mongolia             1
# Montenegro           1
# Length: 127, dtype: int64

# %%
country_new.head(10).plot.bar();

# %%
cw = country_new.value_counts().reset_index()
cw.columns = ['country_name', 'Tw']
cw = cw.sort_values(by="Tw", ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(y= cw['country_name'], x= cw['Tw'], palette="YlOrRd" )
plt.title('En Çok İzlenen 10 Ülke')
plt.xlabel('Ülke')
plt.ylabel('Toplam İzlenme Sayısı')
plt.tight_layout()
plt.show()

# %%
cw
# Out:
#      country_name    Tw
# 0   United States  3689
# 1           India  1046
# 2  United Kingdom   804
# 3          Canada   445
# 4          France   393
# 5           Japan   318
# 6           Spain   232
# 7     South Korea   231
# 8         Germany   226
# 9          Mexico   169

# %%
cw['country_name']
# Out:
# 0     United States
# 1             India
# 2    United Kingdom
# 3             Japan
# 4       South Korea
# 5            Canada
# 6             Spain
# 7            France
# 8            Mexico
# 9             Egypt
# Name: country_name, dtype: object

# %%
# Her bir ülkenin toplam izlenme sayısını bulalım
ulke_toplam_izlenme = df['country'].value_counts().reset_index()
ulke_toplam_izlenme.columns = ['country', 'Toplam_Izlenme']

# Toplam izlenme sayısına göre sıralayalım
ulke_toplam_izlenme = ulke_toplam_izlenme.sort_values(by='Toplam_Izlenme', ascending=False)

# En çok izlenen 10 ülkeyi seçelim
en_cok_izlenen_10_ulke = ulke_toplam_izlenme.head(10)

# Veriyi görselleştirelim
plt.figure(figsize=(10, 6))
plt.barh(en_cok_izlenen_10_ulke['country'], en_cok_izlenen_10_ulke['Toplam_Izlenme'], color='red' )
plt.title('En Çok İzlenen 10 Ülke')
plt.xlabel('Ülke')
plt.ylabel('Toplam İzlenme Sayısı')
plt.tight_layout()
plt.show()

# %% [markdown]
# # ChatGpt kod açıklaması
# **ulke_toplam_izlenme = df['country'].value_counts().reset_index()
# bu satırı açıklar mısın?**
#
# df['Country']: DataFrame üzerinde "Country" sütununu seçer. Bu, her bir film kaydının hangi ülkeye ait olduğunu içeren sütundur.
#
# value_counts(): Seçilen sütundaki unique değerlerin sayısını hesaplar. Yani, her bir ülkenin kaç kez tekrarlandığını sayar ve bu sayıları içeren bir Seri (Series) döndürür. Bu durumda, her bir ülkenin izlenme sayısını içeren bir Series oluşturur.
#
# reset_index(): Bu, value_counts() tarafından oluşturulan Series'in indexini sıfırlar ve bir DataFrame'e dönüştürür. Yani, her bir ülkenin izlenme sayısını içeren bir DataFrame elde ederiz. Bu DataFrame'in iki sütunu olacaktır: "index" ve "Country".
#
# Sonuç olarak, ulke_toplam_izlenme adlı DataFrame, her bir ülkenin izlenme sayısını içeren bir tablo olacaktır. "index" sütunu ülke isimlerini, "Country" sütunu ise her ülkenin toplam izlenme sayısını içerecektir. Bu DataFrame'i daha sonra kullanarak istediğiniz analizleri veya görselleştirmeleri gerçekleştirebilirsiniz.

# %% [markdown]
# **burada    ulke_toplam_izlenme.columns = ['Country', 'Toplam_Izlenme']   kodunu açıklar mısın**
#
# Evet, tabii ki! Bu satır, pandas DataFrame'inin sütun isimlerini değiştirmek için kullanılır. ulke_toplam_izlenme DataFrame'i,
# "Country" ve "Toplam_Izlenme" adında iki sütuna sahiptir, ancak bu isimleri daha açıklayıcı hale getirmek için kullanılır.
#
# Önceki adımda, value_counts() fonksiyonu index ve values adlarında sütunlara sahip bir DataFrame döndürür.
# Ancak bu sütun isimleri her zaman standart değildir (bazen "index" ve "values" olarak adlandırılır). Bu durumda,
# sütun isimlerini değiştirmek, daha sonra bu isimlere daha kolay erişim sağlamak için faydalı olabilir.
#
# Bu satırın amacı şudur:
# Bu satır, ulke_toplam_izlenme DataFrame'inin sütun isimlerini "Country" ve "Toplam_Izlenme" olarak değiştirir.
# Bu şekilde, daha sonraki kod bloklarında bu isimleri kullanarak sütunlara daha kolay ve anlamlı bir şekilde erişebiliriz.
# Örneğin, ulke_toplam_izlenme['Country'] ve ulke_toplam_izlenme['Toplam_Izlenme'] şeklinde belirli sütunlara erişim sağlayabiliriz.

# %%
pip install WordCloud

# %%
from wordcloud import WordCloud

# %%
df['country'] = df['country'].astype(str)

plt.subplots(figsize=(25,15))
wordcloud=WordCloud(
background_color="white",
    width=1920,
    height=1080
).generate(" ".join(df.country))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("country.png")
plt.show()

# %%
df.listed_in.value_counts().sort_values( ascending=False).head(10)
# Out:
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            220
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: listed_in, dtype: int64

# %%
genre_new = df.listed_in.str.split(', ', expand = True).stack()
genre_new
# Out:
# 0     0               Documentaries
# 1     0      International TV Shows
#       1                   TV Dramas
#       2                TV Mysteries
# 2     0              Crime TV Shows
#                      ...
# 8805  0    Children & Family Movies
#       1                    Comedies
# 8806  0                      Dramas
#       1        International Movies
#       2            Music & Musicals
# Length: 19323, dtype: object

# %%
genre_new.value_counts()
# Out:
# International Movies            2752
# Dramas                          2427
# Comedies                        1674
# International TV Shows          1351
# Documentaries                    869
# Action & Adventure               859
# TV Dramas                        763
# Independent Movies               756
# Children & Family Movies         641
# Romantic Movies                  616
# TV Comedies                      581
# Thrillers                        577
# Crime TV Shows                   470
# Kids' TV                         451
# Docuseries                       395
# Music & Musicals                 375
# Romantic TV Shows                370
# Horror Movies                    357
# Stand-Up Comedy                  343
# Reality TV                       255
# British TV Shows                 253
# Sci-Fi & Fantasy                 243
# Sports Movies                    219
# Anime Series                     176
# Spanish-Language TV Shows        174
# ...

# %%
genre = genre_new.value_counts().reset_index()
genre.columns = ["kind", "cnt"]
genre = genre. sort_values(by="cnt", ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(genre.kind, genre.cnt , palette="autumn_r")
plt.title("En çok izlenen 10 tür")
plt.xlabel("Tür")
plt.ylabel("Toplam izlenme sayısı")
plt.xticks(rotation=90)
plt.tight_layout;

# %%
genre_new.head(10).plot.bar();

# %%
fig, ax = plt.subplots()
ax = sns.countplot(data = df, x = "type",palette="autumn_r")
ax.set_title("Distribution of Type", color= "red")

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+0.6));

# %%
df.type.value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
x =df.type.value_counts().values
mylabels= df.type.value_counts().index

plt.figure(figsize=(10,8))
plt.title("Distribution of Type", color= "red")
plt.pie(x, labels=mylabels, labeldistance= 0.5, autopct= "%.2f",
        startangle=90, shadow=True, explode = [0.1,0])
plt.legend();

# %%
fig, ax = plt.subplots(figsize=(13,8))

ax = sns.countplot(data = df, x = "rating")
ax.set_title("Distribution of Rating", color= "red",fontweight= "bold")
plt.xticks(rotation=90);

# %%
df.title
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
plt.subplots(figsize=(25,15))
wordcloud=WordCloud(
background_color="white",
    width=1920,
    height=1080
).generate(" ".join(df.title))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("title.png")
plt.show()

# %%
plt.subplots(figsize=(25,15))
wordcloud=WordCloud(
background_color="white",
    width=1920,
    height=1080
).generate(" ".join(genre_new))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("genre.png")
plt.show()

# %% [markdown]
# ## Summary:
# In summary, the analysis of the available Netflix data provides valuable insights into audience preferences, popular genres, highly-rated titles, and the distribution between movies and TV shows. These insights can be applied to inform content strategies, target marketing efforts, and make data-driven decisions within the streaming industry. However, it is important to validate the findings, continuously monitor audience preferences, and consider gathering additional data to enhance the analysis and gain a deeper understanding of viewer behaviour and engagement.
