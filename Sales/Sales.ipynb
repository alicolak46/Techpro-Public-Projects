# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('sales_data.csv')
df.head(10)
# Out:
#      OrderID ProductID                     ProductName           UnitPrice  \
# 0   ORD00076    PRD991  Smartwatch, Camera, Headphones  154.88971109205679
# 1   ORD00491    PRD400                          Laptop                free
# 2   ORD00369    PRD957                          Camera   770.6350827794904
# 3   ORD00490    PRD232                             NaN   82.95197721398569
# 4   ORD00228    PRD123                          Laptop  250.42946041877397
# 5   ORD00216    PRD720                      Headphones   604.8690048155798
# 6   ORD00337    PRD996                      Smartwatch  1144.3932606296573
# 7  ORD00395#    PRD942                          Laptop                   -
# 8   ORD00418    PRD563                          Laptpo                 Ask
# 9   ORD00066   PRD101#                      Smartwatch   342.3513003762941
#
#    Quantity  Discount CustomerID             SaleDate Salesperson   Region
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      525 non-null    object
#  1   ProductID    525 non-null    object
#  2   ProductName  489 non-null    object
#  3   UnitPrice    498 non-null    object
#  4   Quantity     525 non-null    int64
#  5   Discount     525 non-null    float64
#  6   CustomerID   470 non-null    object
#  7   SaleDate     518 non-null    object
#  8   Salesperson  473 non-null    object
#  9   Region       525 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 41.1+ KB

# %%
#df.isna().sum().sort_values(ascending=False)
df.isna().sum()[df.isna().sum() > 0]
# Out:
# ProductName    36
# UnitPrice      27
# CustomerID     55
# SaleDate        7
# Salesperson    52
# dtype: int64

# %%
df.OrderID
# Out:
# 0       ORD00076
# 1       ORD00491
# 2       ORD00369
# 3       ORD00490
# 4       ORD00228
#          ...
# 520    ORD00406!
# 521     ORD00326
# 522     ORD00276
# 523     ORD00367
# 524     ORD00379
# Name: OrderID, Length: 525, dtype: object

# %%
df.OrderID.str.lstrip("ORD").str.rstrip("!") #df.OrderID.str.rstrip("!")
# Out:
# 0      00076
# 1      00491
# 2      00369
# 3      00490
# 4      00228
#        ...
# 520    00406
# 521    00326
# 522    00276
# 523    00367
# 524    00379
# Name: OrderID, Length: 525, dtype: object

# %%
df.OrderID = df.OrderID.str.lstrip("ORD").str.rstrip("!")

# %%
df[df.OrderID.str.isnumeric()==False]
# Out:
#     OrderID ProductID                             ProductName  \
# 7    00395#    PRD942                                  Laptop
# 22   00426#    PRD633          Smartwatch, Smartwatch, Laptop
# 39   00124#    PRD772                              Smartwatch
# 105  00031#    PRD417                                  Laptop
# 121  00020#    PRD243                              Headphones
# 143  00205*    PRD293                                  Camera
# 178  00458*    PRD545                              Smartwatch
# 206  00059*    PRD960                                     NaN
# 211  00168#    PRD598                                  Camera
# 225  00236*    PRD326                                  Camera
# 232  00196*    PRD687                                  Laptop
# 238  00398*   PRD726#  Laptop, Camera, Smartphone, Smartwatch
# 258  00294#    PRD112                              Smartwatch
# 372  00478#    PRD898                                  Laptop
# ...

# %%
df.OrderID.str.rstrip("#").str.rstrip("*") #df.OrderID.str.rstrip("#" , "*") Ayrı ayrı yazmamız mı gerekiyor?
# Out:
# 0      00076
# 1      00491
# 2      00369
# 3      00490
# 4      00228
#        ...
# 520    00406
# 521    00326
# 522    00276
# 523    00367
# 524    00379
# Name: OrderID, Length: 525, dtype: object

# %%
df.OrderID = df.OrderID.str.rstrip("#").str.rstrip("*")

# %%
df[df.OrderID.str.isnumeric()==False]
# Out:
# Empty DataFrame
# Columns: [OrderID, ProductID, ProductName, UnitPrice, Quantity, Discount, CustomerID, SaleDate, Salesperson, Region]
# Index: []

# %%
df.OrderID.astype(int)
# Out:
# 0       76
# 1      491
# 2      369
# 3      490
# 4      228
#       ...
# 520    406
# 521    326
# 522    276
# 523    367
# 524    379
# Name: OrderID, Length: 525, dtype: int32

# %%
df.OrderID=df.OrderID.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      525 non-null    int32
#  1   ProductID    525 non-null    object
#  2   ProductName  489 non-null    object
#  3   UnitPrice    498 non-null    object
#  4   Quantity     525 non-null    int64
#  5   Discount     525 non-null    float64
#  6   CustomerID   470 non-null    object
#  7   SaleDate     518 non-null    object
#  8   Salesperson  473 non-null    object
#  9   Region       525 non-null    object
# dtypes: float64(1), int32(1), int64(1), object(7)
# memory usage: 39.1+ KB

# %%
df.ProductID
# Out:
# 0      PRD991
# 1      PRD400
# 2      PRD957
# 3      PRD232
# 4      PRD123
#         ...
# 520    PRD409
# 521    PRD708
# 522    PRD279
# 523    PRD433
# 524    PRD748
# Name: ProductID, Length: 525, dtype: object

# %%
df.ProductID.str.lstrip("PRD")
# Out:
# 0      991
# 1      400
# 2      957
# 3      232
# 4      123
#       ...
# 520    409
# 521    708
# 522    279
# 523    433
# 524    748
# Name: ProductID, Length: 525, dtype: object

# %%
df.ProductID = df.ProductID.str.lstrip("PRD")

# %%
df[df.ProductID.str.isnumeric()==False]
# Out:
#      OrderID ProductID                             ProductName  \
# 9         66      101#                              Smartwatch
# 14       397      641*                                  Laptop
# 18        69      947!                              Smartphone
# 23       116      347*                              Headphones
# 50       298      443*          Laptop, Smartwatch, Headphones
# 106      334      558#                  Smartphone, Smartwatch
# 115      400      295*                                  Camera
# 125      453      606#      Camera, Headphones, Laptop, Camera
# 137      388      423#  Laptop, Camera, Smartwatch, Smartphone
# 150      461      650#                          Camera, Camera
# 170       70      988*                                  Camera
# 171      295      568!                              Headphones
# 210      291      257*  Laptpo, Camera, Smartwatch, Headphones
# 238      398      726#  Laptop, Camera, Smartphone, Smartwatch
# ...

# %%
#df.ProductID.str.lstrip("#").str.lstrip("!").str.lstrip("*") Bu kodu uyguladığımda değişiklik yapmadı, neden? Sürüm Farkı vb.?
df.ProductID.str.strip("#*!")
# Out:
# 0      991
# 1      400
# 2      957
# 3      232
# 4      123
#       ...
# 520    409
# 521    708
# 522    279
# 523    433
# 524    748
# Name: ProductID, Length: 525, dtype: object

# %%
#df.ProductID = df.ProductID.str.lstrip("#").str.lstrip("!").str.lstrip("*")
df.ProductID = df.ProductID.str.strip("#*!")

# %%
df[df.ProductID.str.isnumeric()==False]
# Out:
# Empty DataFrame
# Columns: [OrderID, ProductID, ProductName, UnitPrice, Quantity, Discount, CustomerID, SaleDate, Salesperson, Region]
# Index: []

# %%
df.ProductID = df.ProductID.astype(int)

# %%
df.dtypes
# Out:
# OrderID          int32
# ProductID        int32
# ProductName     object
# UnitPrice       object
# Quantity         int64
# Discount       float64
# CustomerID      object
# SaleDate        object
# Salesperson     object
# Region          object
# dtype: object

# %%
df.isnull().sum().sort_values(ascending=False)[df.isnull().sum().sort_values(ascending=False)>0]
# Out:
# CustomerID     55
# Salesperson    52
# ProductName    36
# UnitPrice      27
# SaleDate        7
# dtype: int64

# %%
df.ProductName
# Out:
# 0      Smartwatch, Camera, Headphones
# 1                              Laptop
# 2                              Camera
# 3                                 NaN
# 4                              Laptop
#                     ...
# 520                        Headphones
# 521                        Smartwatch
# 522        Laptop, Headphones, Camera
# 523                        Smartphone
# 524                        Smartphone
# Name: ProductName, Length: 525, dtype: object

# %%
df.ProductName.unique()
# Out:
# array(['Smartwatch, Camera, Headphones', 'Laptop', 'Camera', nan,
#        'Headphones', 'Smartwatch', 'Laptpo', 'Smartphone',
#        'Laptop, Smartwatch, Laptop, Laptop',
#        'Smartwatch, Smartphone, Smartphone',
#        'Smartwatch, Smartwatch, Laptop', 'Smartphone, Smartphone, Camera',
#        'Smartwatch, Headphones, Laptop, Smartwatch',
#        'Smartwatch, Headphones', 'Camera, Smartwatch, Laptop, Laptop',
#        'Camra', 'Headphones, Headphones, Smartphone, Smartphone',
#        'Laptop, Smartwatch', 'Laptop, Smartwatch, Headphones',
#        'Smartphone, Headphones, Camera, Headphones',
#        'Laptop, Laptop, Smartphone, Headphones',
#        'Laptop, Smartphone, Headphones, Smartphone',
#        'Smartphone, Laptop, Smartwatch, Smartwatch',
#        'Headphones, Camera, Smartphone, Headphones',
#        'Headphones, Smartphone, Headphones, Smartphone',
#        'Smartwach, Camera, Smartphone',
#        'Smartphone, Smartphone, Smartphone, Camera',
# ...

# %%
df.UnitPrice
# Out:
# 0      154.88971109205679
# 1                    free
# 2       770.6350827794904
# 3       82.95197721398569
# 4      250.42946041877397
#               ...
# 520    233.87955031098537
# 521     845.8720285990315
# 522     635.4792729210393
# 523     964.8166001885094
# 524      701.998403686702
# Name: UnitPrice, Length: 525, dtype: object

# %%
df.UnitPrice.value_counts().head(100)
# Out:
# UnitPrice
# -                    35
# Check                21
# free                 17
# Ask                  11
# Free                 10
#                      ..
# 689.7328922094955     1
# 680.523339700429      1
# 561.9530684990948     1
# 427.1545533019972     1
# 787.9035860128024     1
# Name: count, Length: 100, dtype: int64

# %%
# df.replace({"?": "Unknown", "!": "aa"}) birden fazla değeri farklı değerlerle değiştirmek istiyorsak dict formatında yazmamız lazım
df.UnitPrice.replace({"-":"", "Check":"", "free":"", "Ask":"", "Free":""})
# Out:
# 0      154.88971109205679
# 1
# 2       770.6350827794904
# 3       82.95197721398569
# 4      250.42946041877397
#               ...
# 520    233.87955031098537
# 521     845.8720285990315
# 522     635.4792729210393
# 523     964.8166001885094
# 524      701.998403686702
# Name: UnitPrice, Length: 525, dtype: object

# %%
df.UnitPrice_1=df.UnitPrice.replace({"-":"", "Check":"", "free":"", "Ask":"", "Free":""})

# %%
df.UnitPrice_1.replace("", np.nan)
# Out:
# 0      154.88971109205679
# 1                     NaN
# 2       770.6350827794904
# 3       82.95197721398569
# 4      250.42946041877397
#               ...
# 520    233.87955031098537
# 521     845.8720285990315
# 522     635.4792729210393
# 523     964.8166001885094
# 524      701.998403686702
# Name: UnitPrice, Length: 525, dtype: object

# %%
df.UnitPrice_1=df.UnitPrice_1.replace("", np.nan)

# %%
df.UnitPrice_1.fillna(df.UnitPrice_1.median()) #sadece nan değer nasıl bulunur?
# Out:
# 0      154.88971109205679
# 1              784.296111
# 2       770.6350827794904
# 3       82.95197721398569
# 4      250.42946041877397
#               ...
# 520    233.87955031098537
# 521     845.8720285990315
# 522     635.4792729210393
# 523     964.8166001885094
# 524      701.998403686702
# Name: UnitPrice, Length: 525, dtype: object

# %%
df.UnitPrice_1= df.UnitPrice_1.fillna(df.UnitPrice_1.median())

# %%
df.UnitPrice_1.astype(float)
# Out:
# 0      154.889711
# 1      784.296111
# 2      770.635083
# 3       82.951977
# 4      250.429460
#           ...
# 520    233.879550
# 521    845.872029
# 522    635.479273
# 523    964.816600
# 524    701.998404
# Name: UnitPrice, Length: 525, dtype: float64

# %%
df.UnitPrice_1=round(df.UnitPrice_1.astype(float),2)

# %%
df.UnitPrice_1
# Out:
# 0      154.89
# 1      784.30
# 2      770.64
# 3       82.95
# 4      250.43
#         ...
# 520    233.88
# 521    845.87
# 522    635.48
# 523    964.82
# 524    702.00
# Name: UnitPrice, Length: 525, dtype: float64

# %%
df.UnitPrice_1.isnull().sum()
# Out:
# 0

# %%
df.UnitPrice=df.UnitPrice_1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      525 non-null    int32
#  1   ProductID    525 non-null    int32
#  2   ProductName  489 non-null    object
#  3   UnitPrice    525 non-null    float64
#  4   Quantity     525 non-null    int64
#  5   Discount     525 non-null    float64
#  6   CustomerID   470 non-null    object
#  7   SaleDate     518 non-null    object
#  8   Salesperson  473 non-null    object
#  9   Region       525 non-null    object
# dtypes: float64(2), int32(2), int64(1), object(5)
# memory usage: 37.0+ KB

# %%
df[df.duplicated()]
# Out:
#      OrderID  ProductID ProductName  UnitPrice  Quantity  Discount CustomerID  \
# 239       80        327      Camera    1223.05        14      0.05   CUST6827
# 280      154        529      Camera    1058.76         2      0.05   CUST7286
# 288      234        366      Laptop    1268.20        17      0.05   CUST3360
# 312      213        953  Headphones     526.78        18      0.00        NaN
# 338      306        593  Smartphone     869.06        19      0.10        NaN
# 355      459        481  Headphones     851.45         1      0.05   CUST1114
# 362      423        362      Camera     784.30        13      0.10   CUST3751
# 382      490        232         NaN      82.95         1      0.15   CUST2238
# 398       56        114   Headphons    1202.45        13      0.15   CUST6416
# 403      233        955       Camra     528.57        11      0.00   CUST8044
# 470      106        660         NaN     480.13        13      0.20        NaN
# ...

# %%
df.duplicated().sum()
# Out:
# 15

# %%
df[df.OrderID==154]
# Out:
#      OrderID  ProductID ProductName  UnitPrice  Quantity  Discount CustomerID  \
# 110      154        529      Camera    1058.76         2      0.05   CUST7286
# 280      154        529      Camera    1058.76         2      0.05   CUST7286
#
#                 SaleDate Salesperson Region
# 110  2023-05-30 00:00:00       Diana   West
# 280  2023-05-30 00:00:00       Diana   West

# %%
df.drop_duplicates(keep='first')
# Out:
#      OrderID  ProductID                     ProductName  UnitPrice  Quantity  \
# 0         76        991  Smartwatch, Camera, Headphones     154.89         8
# 1        491        400                          Laptop     784.30        19
# 2        369        957                          Camera     770.64        16
# 3        490        232                             NaN      82.95         1
# 4        228        123                          Laptop     250.43        11
# ..       ...        ...                             ...        ...       ...
# 520      406        409                      Headphones     233.88        12
# 521      326        708                      Smartwatch     845.87        12
# 522      276        279      Laptop, Headphones, Camera     635.48        12
# 523      367        433                      Smartphone     964.82         8
# 524      379        748                      Smartphone     702.00         3
#
# ...

# %%
a=df.copy()

# %%
df.drop_duplicates(keep='first', inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 510 entries, 0 to 524
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      510 non-null    int32
#  1   ProductID    510 non-null    int32
#  2   ProductName  476 non-null    object
#  3   UnitPrice    510 non-null    float64
#  4   Quantity     510 non-null    int64
#  5   Discount     510 non-null    float64
#  6   CustomerID   458 non-null    object
#  7   SaleDate     503 non-null    object
#  8   Salesperson  459 non-null    object
#  9   Region       510 non-null    object
# dtypes: float64(2), int32(2), int64(1), object(5)
# memory usage: 39.8+ KB

# %%
df.SaleDate
# Out:
# 0      2022-03-31 00:00:00
# 1      2021-01-06 00:00:00
# 2                  Unknown
# 3      2023-08-14 00:00:00
# 4      2020-08-15 00:00:00
#               ...
# 520    2022-11-07 00:00:00
# 521    2022-09-25 00:00:00
# 522    2022-01-29 00:00:00
# 523    2020-02-14 00:00:00
# 524    2021-08-16 00:00:00
# Name: SaleDate, Length: 510, dtype: object

# %%
df.SaleDate.value_counts()
# Out:
# SaleDate
# TBD                    10
# Unknown                 8
# 2022-03-26 00:00:00     3
# 2020-04-01 00:00:00     3
# 2020-07-21 00:00:00     3
#                        ..
# 2021-06-03 00:00:00     1
# 2023-10-08 00:00:00     1
# 2022-03-22 00:00:00     1
# 2023-12-05 00:00:00     1
# 2021-08-16 00:00:00     1
# Name: count, Length: 408, dtype: int64

# %%
df.SaleDate.replace({"TBD":np.nan, "Unknown":np.nan })
# Out:
# 0      2022-03-31 00:00:00
# 1      2021-01-06 00:00:00
# 2                      NaN
# 3      2023-08-14 00:00:00
# 4      2020-08-15 00:00:00
#               ...
# 520    2022-11-07 00:00:00
# 521    2022-09-25 00:00:00
# 522    2022-01-29 00:00:00
# 523    2020-02-14 00:00:00
# 524    2021-08-16 00:00:00
# Name: SaleDate, Length: 510, dtype: object

# %%
df.SaleDate=df.SaleDate.replace({"TBD":np.nan, "Unknown":np.nan })

# %%
df.SaleDate.fillna(df.SaleDate.mode())
# Out:
# 0      2022-03-31 00:00:00
# 1      2021-01-06 00:00:00
# 2      2022-03-26 00:00:00
# 3      2023-08-14 00:00:00
# 4      2020-08-15 00:00:00
#               ...
# 520    2022-11-07 00:00:00
# 521    2022-09-25 00:00:00
# 522    2022-01-29 00:00:00
# 523    2020-02-14 00:00:00
# 524    2021-08-16 00:00:00
# Name: SaleDate, Length: 510, dtype: object

# %%
df.SaleDate= df.SaleDate.fillna(df.SaleDate.mode())

# %%
df.SaleDate=pd.to_datetime(df["SaleDate"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 510 entries, 0 to 524
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      510 non-null    int32
#  1   ProductID    510 non-null    int32
#  2   ProductName  476 non-null    object
#  3   UnitPrice    510 non-null    float64
#  4   Quantity     510 non-null    int64
#  5   Discount     510 non-null    float64
#  6   CustomerID   458 non-null    object
#  7   SaleDate     486 non-null    datetime64[ns]
#  8   Salesperson  459 non-null    object
#  9   Region       510 non-null    object
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(1), object(4)
# memory usage: 39.8+ KB

# %%
df.head(3)
# Out:
#    OrderID  ProductID                     ProductName  UnitPrice  Quantity  \
# 0       76        991  Smartwatch, Camera, Headphones     154.89         8
# 1      491        400                          Laptop     784.30        19
# 2      369        957                          Camera     770.64        16
#
#    Discount CustomerID   SaleDate Salesperson Region
# 0      0.15   CUST7975 2022-03-31         NaN  North
# 1      0.20   CUST6889 2021-01-06     Charlie  North
# 2      0.05   CUST4092 2022-03-26       Alice   West

# %%
# Out:
# 121
