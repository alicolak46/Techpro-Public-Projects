# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Effective Data Visualization Project</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Watsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |

# %% [markdown]
# # Effective Data Visualization2 Project with Cancer, crypto_daily_prices, crypto_daily_returns,stocks_daily_prices and  stocks_daily_returns Data

# %% [markdown]
# ## CODING TASK #1. PLOT PIE CHART USING MATPLOTLIB

# %% [markdown]
# - **The plot method on Pandas Series and DataFrames is just a simple wrapper around plt.plot():**
# - **Define a Pandas Dataframe with all crypto allocation in a given portfolio**
# - **Note that total sum = 100%**
# - **Use matplotlib to plot a pie chart**

# %%
import pandas as pd

import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
crypto_allocation = pd.DataFrame({
    'Crypto': ['XRP', 'BTC', 'LTC', 'ADA', 'ETH'],
    'Allocation': [20, 20, 20, 20, 20] })

# %%
crypto_allocation.head()
# Out:
#   Crypto  Allocation
# 0    XRP          20
# 1    BTC          20
# 2    LTC          20
# 3    ADA          20
# 4    ETH          20

# %%
plt.figure(figsize=(10, 8))

plt.pie(crypto_allocation.Allocation, labels = crypto_allocation.Crypto, labeldistance = 0.5, autopct = "%.2f")

plt.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #1:**
# - **Assume that you became bullish on XRP and decided to allocate 60% of your assets in it. You also decided to equally divide the rest of your assets in other coins (BTC, LTC, ADA, and ETH). Change the allocations and plot the pie chart.**
# - **Use 'explode' to increase the separation between XRP and the rest of the portfolio (External Research is Required)**

# %%
crypto_allocation = pd.DataFrame({
    'Crypto': ['XRP', 'BTC', 'LTC', 'ADA', 'ETH'],
    'Allocation': [60, 10, 10, 10, 10] })

# %%
plt.figure(figsize=(10, 8))

explode = [0.1, 0, 0, 0,0]

plt.pie(crypto_allocation.Allocation, 
        labels = crypto_allocation.Crypto,
        explode=explode, 
        labeldistance = 0.8, 
        autopct = "%.3f")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## CODING TASK #2. PLOT SINGLE & MULTIPLE LINE PLOTS USING MATPLOTLIB
# - **Use Pandas read_csv to read crypto_daily_prices (BTC, ETH, and LTC)**
# - **Use matplotlib on the Pandas DataFrame to plot the data**

# %%
investments_df = pd.read_csv('crypto_daily_prices.csv')
investments_df
# Out:
#            Date           BTC          ETH       ADA
# 0     9/17/2014    457.334015          NaN       NaN
# 1     9/18/2014    424.440002          NaN       NaN
# 2     9/19/2014    394.795990          NaN       NaN
# 3     9/20/2014    408.903992          NaN       NaN
# 4     9/21/2014    398.821014          NaN       NaN
# ...         ...           ...          ...       ...
# 2828  6/15/2022  22572.839840  1233.206421  0.533296
# 2829  6/16/2022  20381.650390  1067.730713  0.475022
# 2830  6/17/2022  20471.482420  1086.519287  0.487392
# 2831  6/18/2022  19017.642580   993.636780  0.456182
# 2832  6/19/2022  19488.886720  1040.510254  0.464109
#
# [2833 rows x 4 columns]

# %%
investments_df.head()
# Out:
#         Date         BTC  ETH  ADA
# 0  9/17/2014  457.334015  NaN  NaN
# 1  9/18/2014  424.440002  NaN  NaN
# 2  9/19/2014  394.795990  NaN  NaN
# 3  9/20/2014  408.903992  NaN  NaN
# 4  9/21/2014  398.821014  NaN  NaN

# %%
investments_df.isnull().sum()
# Out:
# Date       0
# BTC        0
# ETH     1149
# ADA     1149
# dtype: int64

# %%
investments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2833 entries, 0 to 2832
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2833 non-null   object
#  1   BTC     2833 non-null   float64
#  2   ETH     1684 non-null   float64
#  3   ADA     1684 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 88.7+ KB

# %%
#pip install missingno

# %%
import missingno as msno
msno.matrix(investments_df);

# %%
investments_df.dropna(inplace=True)

# %%
investments_df.isnull().sum()
# Out:
# Date    0
# BTC     0
# ETH     0
# ADA     0
# dtype: int64

# %%
investments_df
# Out:
#             Date           BTC          ETH       ADA
# 1149   11/9/2017   7143.580078   320.884003  0.032053
# 1150  11/10/2017   6618.140137   299.252991  0.027119
# 1151  11/11/2017   6357.600098   314.681000  0.027437
# 1152  11/12/2017   5950.069824   307.907989  0.023977
# 1153  11/13/2017   6559.490234   316.716003  0.025808
# ...          ...           ...          ...       ...
# 2828   6/15/2022  22572.839840  1233.206421  0.533296
# 2829   6/16/2022  20381.650390  1067.730713  0.475022
# 2830   6/17/2022  20471.482420  1086.519287  0.487392
# 2831   6/18/2022  19017.642580   993.636780  0.456182
# 2832   6/19/2022  19488.886720  1040.510254  0.464109
#
# [1684 rows x 4 columns]

# %%
msno.matrix(investments_df);

# %%
investments_df["Date"]=pd.to_datetime(investments_df["Date"])

# %%
investments_df["Date"].dt.year
# Out:
# 1149    2017
# 1150    2017
# 1151    2017
# 1152    2017
# 1153    2017
#         ...
# 2828    2022
# 2829    2022
# 2830    2022
# 2831    2022
# 2832    2022
# Name: Date, Length: 1684, dtype: int32

# %%
investments_df["Year"]=investments_df["Date"].dt.year

# %%
investments_df["Year"]
# Out:
# 1149    2017
# 1150    2017
# 1151    2017
# 1152    2017
# 1153    2017
#         ...
# 2828    2022
# 2829    2022
# 2830    2022
# 2831    2022
# 2832    2022
# Name: Year, Length: 1684, dtype: int32

# %%
investments_df.head()
# Out:
#            Date          BTC         ETH       ADA  Year
# 1149 2017-11-09  7143.580078  320.884003  0.032053  2017
# 1150 2017-11-10  6618.140137  299.252991  0.027119  2017
# 1151 2017-11-11  6357.600098  314.681000  0.027437  2017
# 1152 2017-11-12  5950.069824  307.907989  0.023977  2017
# 1153 2017-11-13  6559.490234  316.716003  0.025808  2017

# %%
investments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1684 entries, 1149 to 2832
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1684 non-null   datetime64[ns]
#  1   BTC     1684 non-null   float64
#  2   ETH     1684 non-null   float64
#  3   ADA     1684 non-null   float64
#  4   Year    1684 non-null   int32
# dtypes: datetime64[ns](1), float64(3), int32(1)
# memory usage: 72.4 KB

# %%
investments_df["Year"]=investments_df["Year"].astype(int)

# %%
plt.figure(figsize=(12, 6))
# Yıllara göre filmlerin sayısını hesapla
ETH_per_year = investments_df['Year'].value_counts().sort_index()

# Çizgi grafiği oluşturma
plt.plot(ETH_per_year.index, ETH_per_year.values, color='blue')

# Eksen isimlerini ekleme
plt.xlabel('Yıl')
plt.ylabel('ETH')

# Başlık ekleme
plt.title('Yıllara Göre ETH Sayısı')

# Line üzerine sayıları yazma

for x, y in zip(ETH_per_year.index, ETH_per_year.values):
    plt.text(x, y + 0.5, str(y), ha='center', va='bottom', fontsize=10)

plt.xlim(2014, 2022)
# Grafiği gösterme
plt.show();

# %%
x = investments_df['Year']
y1 = investments_df['ETH']
y2 = investments_df['BTC']
y3 = investments_df['ADA']


fig1, ax1 = plt.subplots(nrows = 2, ncols = 2, figsize= (20, 20))

ax1[0, 0].plot(x, y1, "tab:blue") # set the color of line chart
ax1[0, 0].set_title("ETH") # setting title of subplot
ax1[0, 0].set_xlabel("X", fontsize = 18)
ax1[0, 0].set_ylabel("Y", fontsize = 18)

ax1[0, 1].plot(x, y2, "tab:orange") # set the color of line chart
ax1[0, 1].set_title("BTC") # setting title of subplot
ax1[0, 1].set_xlabel("X", fontsize = 18)
ax1[0, 1].set_ylabel("Y", fontsize = 18)


ax1[1, 0].plot(x, y3, "r-") # set the color of line chart
ax1[1, 0].set_title("ADA") # setting title of subplot
ax1[1, 0].set_xlabel("X", fontsize = 18)
ax1[1, 0].set_ylabel("Y", fontsize = 18)


ax1[1, 1].plot(y1, x, "r-") # set the color of line chart
ax1[1, 1].set_title("Y1-X") # setting title of subplot
ax1[1, 1].set_xlabel("X", fontsize = 18)
ax1[1, 1].set_ylabel("Y", fontsize = 18)

plt.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #2:**
# - **Use subplots attribute to plot separate figures for BTC, ETH, and ADA**

# %%
 # Create separate figures and axes using subplots
fig, axs = plt.subplots(3, 1, figsize=(10, 12))

# Plot BTC data
axs[0].plot(investments_df["BTC"], label='BTC Price')
axs[0].set_title('BTC Price')
axs[0].legend()

# Plot ETH data
axs[1].plot(investments_df["ETH"], label='ETH Price')
axs[1].set_title('ETH Price')
axs[1].legend()

# Plot ADA data
axs[2].plot(investments_df["ADA"], label='ADA Price')
axs[2].set_title('ADA Price')
axs[2].legend()

 plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# #### Her üç kripto para hemen hemen aynı zamanlarda yükselip azalıyor.

# %% [markdown]
# ## CODING TASK #3. PLOT SCATTERPLOTS USING MATPLOTLIB
# - **Read daily return data using pandas**
# - **Plot Daily returns of BTC vs. ETH**

# %%
daily_return_df = pd.read_csv('crypto_daily_returns.csv')
daily_return_df
# Out:
#            Date       BTC        ETH        ADA
# 0     9/17/2014  0.000000   0.000000   0.000000
# 1     9/18/2014 -7.192558        NaN        NaN
# 2     9/19/2014 -6.984264        NaN        NaN
# 3     9/20/2014  3.573492        NaN        NaN
# 4     9/21/2014 -2.465854        NaN        NaN
# ...         ...       ...        ...        ...
# 2828  6/15/2022  1.648355   1.778018  10.097317
# 2829  6/16/2022 -9.707194 -13.418330 -10.927140
# 2830  6/17/2022  0.440750   1.759673   2.604094
# 2831  6/18/2022 -7.101781  -8.548629  -6.403471
# 2832  6/19/2022  2.477931   4.717365   1.737703
#
# [2833 rows x 4 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(daily_return_df.BTC, daily_return_df.ETH)

ax.set_xlabel("BTC")
ax.set_ylabel("ETH")
ax.set_title(" Daily returns of BTC vs. ETH")

plt.show()

# %% [markdown]
# #### ETH ve BTC arasında doğrusal bir ilişki var. Birisi artarken diğeride artıyor. Biri azalırken diğeri de azalıyor.

# %% [markdown]
# **PRACTICE OPPORTUNITY #3:**
# - **Plot the daily returns of BTC vs. ADA, choose your favourite color!**

# %%
fig, ax = plt.subplots()

ax.scatter(daily_return_df.BTC, daily_return_df.ETH,c="g")

ax.set_xlabel("BTC")
ax.set_ylabel("ADA")
ax.set_title(" Daily returns of BTC vs. ADA")

plt.show()

# %% [markdown]
# ## CODING TASK #4. PLOT HISTOGRAMS USING MATPLOTLIB
# - **A histogram represents data using bars with various heights**
# - **Each bar groups numbers into specific ranges**
# - **Taller bars show that more data falls within that specific range**
# - **Plot the histogram of the returns**

# %%
daily_return_df = pd.read_csv('crypto_daily_returns.csv')
daily_return_df
# Out:
#            Date       BTC        ETH        ADA
# 0     9/17/2014  0.000000   0.000000   0.000000
# 1     9/18/2014 -7.192558        NaN        NaN
# 2     9/19/2014 -6.984264        NaN        NaN
# 3     9/20/2014  3.573492        NaN        NaN
# 4     9/21/2014 -2.465854        NaN        NaN
# ...         ...       ...        ...        ...
# 2828  6/15/2022  1.648355   1.778018  10.097317
# 2829  6/16/2022 -9.707194 -13.418330 -10.927140
# 2830  6/17/2022  0.440750   1.759673   2.604094
# 2831  6/18/2022 -7.101781  -8.548629  -6.403471
# 2832  6/19/2022  2.477931   4.717365   1.737703
#
# [2833 rows x 4 columns]

# %%
fig, ax = plt.subplots( 1, figsize=(10, 5))
sns.histplot(x=daily_return_df.ETH, kde=True, );

# %%
mu = round(daily_return_df['BTC'].mean(), 2) # mean of distribution
sigma = round(daily_return_df['BTC'].std(), 2) # standard deviation of distribution
 
num_bins = 40

# %%
# BTC'nin günlük getirilerini seç
btc_returns = daily_return_df['BTC']

plt.figure(figsize=(10, 6))
plt.hist(btc_returns, bins=40, color='blue', alpha=0.7, label='BTC Günl')
mu = round(daily_return_df['BTC'].mean(), 2) # mean of distribution
sigma = round(daily_return_df['BTC'].std(), 2) # standard deviation of distribution 
num_bins = 40

plt.axvline(mu, color='red', linestyle='dashed', linewidth=2, label=f'MEAN ({mu})')
plt.axvline(sigma, color='red', linestyle='dashed', linewidth=2, label=f'STD ({sigma})')

plt.title('BTC Günlük Getiri Histogramı')
plt.xlabel('Günlük Getiri')
plt.ylabel('Frekans')
plt.legend()
plt.show()

# %% [markdown]
# ####

# %%
fig, ax = plt.subplots(1,3)
ax[0].hist(daily_return_df.ETH, bins=num_bins,color="r")
ax[1].hist(daily_return_df.ADA, bins=num_bins,color="g")
ax[2].hist(daily_return_df.BTC, bins=num_bins,color="b")

plt.tight_layout()
plt.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #4:**
# - **Plot the histogram for BTC and ETH returns using 60 bins. Display all histograms on the same figure**

# %%
fig, ax = plt.subplots(1,2)
ax[0].hist(daily_return_df.ETH, bins=60,color="green")
ax[1].hist(daily_return_df.BTC, bins=60,color="purple")

ax[0].set_title("ETH") # setting title of subplot
ax[0].set_xlabel("Günlük Getiri", fontsize = 8)
ax[0].set_ylabel("Frekans", fontsize = 8)

ax[1].set_title("BTC") # setting title of subplot
ax[1].set_xlabel("Günlük Getiri", fontsize = 8)
ax[1].set_ylabel("Frekans", fontsize = 8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### ETH nin günlük getirisi BTC ye göre daha az

# %% [markdown]
# ## CODING TASK #5. PLOT SCATTERPLOT & COUNTPLOT USING SEABORN
# - **Seaborn is a visualization library that sits on top of matplotlib**
# - **Seaborn offers enhanced features compared to matplotlib**
# - **https://seaborn.pydata.org/examples/index.html*/*
# - **Check out the head of the dataframe**
# - **Check out the tail of the dataframe**
# - **Plot scatter plot between mean area and mean smoothness**
# - **Let's print out countplot to know how many samples belong to class #0 and #1**

# %%
# import libraries 
import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
import seaborn as sns # Statistical data visualization

# %%
# Import Cancer data 
cancer_df = pd.read_csv('cancer.csv')

# %%
cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
cancer_df.tail()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
# ...

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = "mean area", data = cancer_df, y = "mean smoothness", hue = "target", palette = "viridis");

# %% [markdown]
# #### Yukarıdaki dağılım grafiğinde mavi noktalar kanser olma riski düşük olanları, yeşil noktalar ise kanser riski yüksek olanları göstermektedir.

# %%
fig, ax = plt.subplots()

ax = sns.countplot(data = cancer_df, x = "target")

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+0.2))

# %% [markdown]
# #### yukarıdaki countplot da 212 kişi kanser değil,357 kişi kanser

# %% [markdown]
# **PRACTICE OPPORTUNITY #5:**
# - **Plot the scatterplot between the mean radius and mean area. Comment on the plot**

# %%
plt.figure(figsize = (10,5))

sns.scatterplot(x = "mean radius", y = "mean area", data = cancer_df, hue = "target");

# %%
# Target alanında Eğer "1" kanser ise ortalama alan ve yarıçap arttıkça kanser olma riski azalıyor.

# %%
# yarıçap ve alan arasında doğrusal bir ilişki var. Zaten alan büyüdükçe yarıçap artar.

# %% [markdown]
# ## CODING TASK #6. PLOT PAIRPLOT, DISPLOT, AND HEATMAPS/CORRELATIONS USING SEABORN

# %% [markdown]
# - **Plot the pairplot**
# - **Strong correlation between the mean radius and mean perimeter, mean area and mean primeter**
# - **plot the distplot**
# - **Displot combines matplotlib histogram function with kdeplot() (Kernel density estimate)**
# - **KDE is used to plot the Probability Density of a continuous variable.**

# %%
selected_means2 = cancer_df[['mean area', 'mean perimeter']] #correlation between the , mean area and mean primeter**

selected_means2
# Out:
#      mean area  mean perimeter
# 0       1001.0          122.80
# 1       1326.0          132.90
# 2       1203.0          130.00
# 3        386.1           77.58
# 4       1297.0          135.10
# ..         ...             ...
# 564     1479.0          142.00
# 565     1261.0          131.20
# 566      858.1          108.30
# 567     1265.0          140.10
# 568      181.0           47.92
#
# [569 rows x 2 columns]

# %%
selected_means1 = cancer_df[['mean radius', 'mean perimeter']] #mean radius and mean perimeter
selected_means1
# Out:
#      mean radius  mean perimeter
# 0          17.99          122.80
# 1          20.57          132.90
# 2          19.69          130.00
# 3          11.42           77.58
# 4          20.29          135.10
# ..           ...             ...
# 564        21.56          142.00
# 565        20.13          131.20
# 566        16.60          108.30
# 567        20.60          140.10
# 568         7.76           47.92
#
# [569 rows x 2 columns]

# %%
## **Strong correlation between the mean radius and mean perimeter, mean area and mean primeter**

sns.pairplot(selected_means1)                     
plt.suptitle('Pairplot: Mean Radius, Mean Perimeter, y=1.05')    #mean radius and mean perimeter

plt.tight_layout()
plt.show()

# %%
#  **Strong correlation between the mean radius and mean perimeter, mean area and mean primeter**

sns.pairplot(selected_means2)
plt.suptitle('Pairplot: Mean area, Mean Perimeter, y=1.05')   # mean area and mean primeter**

plt.tight_layout()
plt.show()

# %%
correlation_matrix = cancer_df[['mean radius','mean perimeter','mean area','mean perimeter']].corr()

# %%
#    **Displot combines matplotlib histogram function with kdeplot() (Kernel density estimate)**
#    **KDE is used to plot the Probability Density of a continuous variable.** 
sns.set(style="whitegrid")
sns.set_context("notebook", font_scale=1.2)

# Create a displot for 'mean radius' based on target class
plt.figure(figsize=(10, 6))
sns.displot(data=cancer_df, x='mean radius', hue='target', kde=True, bins=20, palette=['blue', 'green'])

plt.title('Displot: Mean Radius by Target Class')
plt.xlabel('Mean Radius')

plt.ylabel('Density')
plt.show()

# %%
correlation_matrix1 = cancer_df[['mean radius','mean perimeter','mean area']].corr()

# %%
sns.heatmap(correlation_matrix1, annot=True, cmap = "viridis");

# %%
## mean radius ve mean perimeyet alanlarının korelasyonu 1 olduğu için bu iki özellikten birisi verisetinden çıkarılabilir. Ya da iki alan birleştirilebilir.

# %%
# Distplot with KDE for mean radius based on target class
plt.figure(figsize=(10, 6))

g = sns.FacetGrid(cancer_df, col="target", height=6)
g.map(sns.distplot, 'mean radius', kde=True, bins=20)

g.set_axis_labels('Mean Radius', 'Density')
g.set_titles("Target Class: {col_name}")

plt.suptitle('Distplot with KDE for Mean Radius in Each Target Class', y=1.02)
plt.tight_layout()
plt.show()

# %%
sns.displot(x="mean radius", data = cancer_df, bins = 50, kde=True);

# %%
sns.displot(x="mean perimeter", data = cancer_df, bins = 50, kde=True);

# %%
class1=cancer_df[cancer_df['target'] == 1]

# %%
class0=cancer_df[cancer_df['target'] == 0]

# %%
class1.head()
# Out:
#     mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 19       13.540         14.36           87.46      566.3          0.09779
# 20       13.080         15.71           85.63      520.0          0.10750
# 21        9.504         12.44           60.34      273.9          0.10240
# 37       13.030         18.42           82.61      523.8          0.08983
# 46        8.196         16.84           51.71      201.9          0.08600
#
#     mean compactness  mean concavity  mean concave points  mean symmetry  \
# 19           0.08129         0.06664             0.047810         0.1885
# 20           0.12700         0.04568             0.031100         0.1967
# 21           0.06492         0.02956             0.020760         0.1815
# 37           0.03766         0.02562             0.029230         0.1467
# 46           0.05943         0.01588             0.005917         0.1769
#
#     mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #6:**
# - **Plot two separate distplot for each target class #0 and target class #1**

# %%
fig, ax = plt.subplots(1, 2, figsize = (12, 6))

sns.scatterplot(x = "mean smoothness", y = "mean compactness", data = class1, s = 300, hue = "target", ax=ax[0],legend='auto')
sns.scatterplot(x = "mean smoothness", y = "mean compactness", data = class0, s = 300, hue = "target", ax=ax[1],legend='auto')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # FINAL CAPSTONE PROJECT

# %% [markdown]
# - In this project, we will visualize stock prices using Seaborn and Matplotlib. 4 Stocks are considered including JP Morgan Chase (JP), Procter and Gamble (P&G) (PG), Apple (AAPL) and United Airlines (UAL).
# - Using the stock_daily_prices.csv and stocks_daily_returns.csv dataset included in the course/workshop package, please do the following:
#     - Import both datasets using Pandas.
#     - Using Matplotlib, plot lineplots that display all 4 stocks daily prices on one single figure.
#     - Using Matplotlib, plot 4 stocks daily prices on multiple subplots.
#     - Using Matplotlib, plot the 4 plots on subplots next to each other (all figures in one row).
#     - Using Matplotlib, plot the scatterplot between Apple and JP Morgan daily returns.
#     - Using Seaborn, plot similar scatterplot between Apple and JP Morgan daily returns.
#     - Assume that you decided to become bullish on AAPL and you allocated 70% of your assets in it. You also decided to equally divide the rest of your assets in other stocks (JPM, PG, and UAL). Using Matplotlib, plot a pie chart that shows these allocations. Use 'explode’ attribute to increase the separation between AAPL and the rest of the portfolio.
#     - Using Matplotlib, plot the histogram for United Airlines and P&G returns using 40 bins with red color. Display the mean and Standard deviation for both stocks on top of the figure. What did you conclude from this graph?
#     - Using Seaborn, plot a heatmap that shows the correlations between stocks daily returns. Comment on the correlation between UAL and P&G.
#     - Plot a 3D plot showing all daily returns from JPM, AAPL and UAL [External Research is required].

# %%
stocks_daily_prices=pd.read_csv("stocks_daily_prices.csv")
stocks_daily_prices.head()
# Out:
#        Date      AAPL        JPM         PG        UAL
# 0  1/2/2008  5.949703  29.448614  47.058838  29.915234
# 1  1/3/2008  5.952452  29.246094  47.058838  29.690800
# 2  1/4/2008  5.498071  28.582682  46.870098  31.000002
# 3  1/7/2008  5.424478  28.868999  47.175980  29.180000
# 4  1/8/2008  5.229351  27.723747  47.299629  24.389999

# %%
stocks_daily_RETURNS=pd.read_csv("stocks_daily_returns.csv")
stocks_daily_RETURNS.head()
# Out:
#        Date      AAPL       JPM        PG        UAL
# 0  1/2/2008  0.000000  0.000000  0.000000   0.000000
# 1  1/3/2008  0.046203 -0.687708  0.000000  -0.750233
# 2  1/4/2008 -7.633517 -2.268378 -0.401072   4.409454
# 3  1/7/2008 -1.338518  1.001718  0.652615  -5.870973
# 4  1/8/2008 -3.597157 -3.967066  0.262103 -16.415356

# %% [markdown]
# ### Matplotlib kullanarak, 4 hisse senedinin günlük fiyatlarını tek bir grafikte gösteren lineplot'lar çizin.

# %%
plt.figure(figsize=(8, 4))

plt.plot(stocks_daily_prices['Date'], stocks_daily_prices['JPM'], label='JP Morgan Chase (JP)')  
plt.plot(stocks_daily_prices['Date'], stocks_daily_prices['PG'], label='Procter and Gamble (P&G) (PG)')
plt.plot(stocks_daily_prices['Date'], stocks_daily_prices['AAPL'], label='Apple (AAPL)')
plt.plot(stocks_daily_prices['Date'], stocks_daily_prices['UAL'], label='United Airlines (UAL)')

plt.title('Stock Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

plt.show()
 ##                                          burda etiketli

# %% [markdown]
# ### Matplotlib kullanarak, 4 hisse senedinin günlük fiyatlarını birden fazla alt grafikte çizin.

# %%
fig, ax = plt.subplots(2,2)

ax[0][0].plot(stocks_daily_prices['Date'], stocks_daily_prices['JPM'], label='JP Morgan Chase (JP)', color='r')
ax[0][0].set_title('JP Morgan Chase (JPM)')

ax[0][1].plot(stocks_daily_prices['Date'], stocks_daily_prices['PG'], label='Procter and Gamble (P&G) (PG)', color='b')
ax[0][1].set_title('Procter and Gamble (P&G) (PG)')

ax[1][0].plot(stocks_daily_prices['Date'], stocks_daily_prices['AAPL'], label='Apple (AAPL)', color='g')
ax[1][0].set_title('Apple (AAPL)')

ax[1][1].plot(stocks_daily_prices['Date'], stocks_daily_prices['UAL'], label='United Airlines (UAL)', color='y')
ax[1][1].set_title('United Airlines (UAL)')
   
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Matplotlib kullanarak, 4 grafiği yan yana alt grafiklerde çizin (tüm figürleri bir sıra halinde)

# %%
fig, ax = plt.subplots(1,4,figsize=(15, 4))

ax[0].plot(stocks_daily_prices['Date'], stocks_daily_prices['JPM'], label='JP Morgan Chase (JP)', color='r')
ax[0].set_title('JP Morgan Chase (JPM)')

ax[1].plot(stocks_daily_prices['Date'], stocks_daily_prices['PG'], label='Procter and Gamble (P&G) (PG)', color='b')
ax[1].set_title('Procter and Gamble (P&G) (PG)')

ax[2].plot(stocks_daily_prices['Date'], stocks_daily_prices['AAPL'], label='Apple (AAPL)', color='g')
ax[2].set_title('Apple (AAPL)')

ax[3].plot(stocks_daily_prices['Date'], stocks_daily_prices['UAL'], label='United Airlines (UAL)', color='y')
ax[3].set_title('United Airlines (UAL)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Matplotlib kullanarak, Apple ve JP Morgan günlük getirileri arasında bir saçılım grafiği çizin.

# %%
stocks_daily_RETURNS
# Out:
#            Date      AAPL       JPM        PG        UAL
# 0      1/2/2008  0.000000  0.000000  0.000000   0.000000
# 1      1/3/2008  0.046203 -0.687708  0.000000  -0.750233
# 2      1/4/2008 -7.633517 -2.268378 -0.401072   4.409454
# 3      1/7/2008 -1.338518  1.001718  0.652615  -5.870973
# 4      1/8/2008 -3.597157 -3.967066  0.262103 -16.415356
# ...         ...       ...       ...       ...        ...
# 3637  6/13/2022 -3.828484 -2.977838 -2.677001 -10.058308
# 3638  6/14/2022  0.667265 -1.663937 -3.119796  -0.081034
# 3639  6/15/2022  2.011147  1.183593 -0.993725   2.433084
# 3640  6/16/2022 -3.965145 -1.715625  0.611284  -8.207972
# 3641  6/17/2022  1.153314 -0.352642 -0.720077   4.312824
#
# [3642 rows x 5 columns]

# %%
stocks_daily_RETURNS['Date'] = pd.to_datetime(stocks_daily_RETURNS['Date'])

stocks_daily_RETURNS.set_index('Date', inplace=True)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(stocks_daily_RETURNS['AAPL'], stocks_daily_RETURNS['JPM'], c='r', alpha=0.7)

plt.title('Apple and JP Morgan Daily')
plt.xlabel('Apple Daily')
plt.ylabel('JP Morgan Daily')

plt.grid(True)
plt.show()

# %% [markdown]
# ### Seaborn kullanarak, Apple ve JP Morgan günlük getirileri arasında benzer bir saçılım grafiği çizin

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x='AAPL', y='JPM', data=stocks_daily_RETURNS, color='r')

plt.title('Apple and JP Morgan daily returns')
plt.show()

# %% [markdown]
# ### AAPL üzerine iyimser olduğunuza karar verdiniz ve varlıklarınızın %70'ini ona ayırdınız. Geri kalan varlıklarınızı (JPM, PG ve UAL) eşit bir şekilde diğer hisse senetlerine bölmeye karar verdiniz. Matplotlib kullanarak, bu tahsisatları gösteren bir pasta grafiği çizin. 'explode' özelliğini kullanarak AAPL ile portföyün geri kalanı arasındaki ayrımı artırın.

# %%
import numpy as np

# %%
plt.figure(figsize=(8,6))

color_list = ['yellow', 'green', 'blue', 'red']
explode = [0.1,0,0,0]

y = np.array([70,10,10,10])
mylabels = ['AAPL','JPM','PG', 'UAL']

plt.pie(y, labels=mylabels, labeldistance = 0.7, autopct = '%.1f', startangle = 90, shadow = True, pctdistance = 0.6,
       colors = color_list,
       explode=explode)

plt.legend(loc = 0)
plt.show()

# %% [markdown]
# ### Matplotlib kullanarak, United Airlines ve P&G getirileri için 40 aralıklı kırmızı renkte bir histogram çizin. Her iki hisse senedinin ortalama ve standart sapmasını grafiğin üst kısmında gösterin. Bu grafikten ne sonuç çıkardınız?

# %%
UAL_mean=stocks_daily_RETURNS["UAL"].mean()

# %%
PG_mean=stocks_daily_RETURNS["PG"].mean()

# %%
UAL_std=stocks_daily_RETURNS["UAL"].std()

# %%
PG_std=stocks_daily_RETURNS["PG"].std()

# %%
sns.set(style = "darkgrid")

sns.histplot(data = stocks_daily_RETURNS, bins=40,color="red", x = "UAL", kde = True);
sns.histplot(data = stocks_daily_RETURNS, bins=40 ,color="red", x = "PG", kde = True);

# %% [markdown]
# ### Seaborn kullanarak, hisse senetleri günlük getirileri arasındaki korelasyonları gösteren bir heatmap çizin. UAL ve P&G arasındaki korelasyon hakkında yorum yapın.

# %%
correlation_matrix = stocks_daily_RETURNS.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

plt.title('Correlation of Stocks Daily Returns')
plt.show()

# %% [markdown]
# ### JPM, AAPL ve UAL'den tüm günlük getirileri gösteren bir 3D çizim çizin [Dış Araştırma gerekir].

# %%
# 3D plot için gerekli verileri seçin
x = stocks_daily_RETURNS['AAPL']
y = stocks_daily_RETURNS['JPM']
z = stocks_daily_RETURNS['UAL']

# Create a 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.scatter(x, y, z, c='blue', marker='o')

# Set labels
ax.set_xlabel('AAPL Daily Returns')
ax.set_ylabel('JPM Daily Returns')
ax.set_zlabel('UAL Daily Returns')

# Set title
ax.set_title('3D Plot of Daily Returns')

plt.show()

# %% [markdown]
# # GREAT JOB!

# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Effective Data Visualization Project</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Watsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |
